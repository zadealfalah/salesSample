# %% [markdown]
# # Package Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from dotenv import load_dotenv
import mysql.connector
import os
import seaborn as sns

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# First we downloaded the excel file from the UCI ML repo.  The sheets were then downloaded as csv and split by sheet (one for 2009-2010, the other for 2010-2011)
#
# Next we read in these csv files to pandas dataframes, add a flag to show the original sheet, combine them, and begin data cleaning.  The flag is for checking if issues occured in reading in the csv or if they were present in the original data.  Can be removed after cleaning.

# %%
# load_dotenv()
# mysqluser = os.getenv("mysqluser")
# mysqlpassword = os.getenv("mysqlpassword")
# mysqlhost = os.getenv("mysqlhost")
# mysqldatabase = os.getenv("mysqldatabase")

# try:
#     cnx = mysql.connector.connect(user=mysqluser, password=mysqlpassword,
#                                 host=mysqlhost, database=mysqldatabase)
#     query = "SELECT * from onlineretail"
#     df = pd.read_sql(query, cnx)
#     cnx.close()
# except Exception as e:
#     cnx.close()
#     print(str(e))

# %%
df1 = pd.read_csv(r"data/online_retail_II_2009_2010.csv", encoding='unicode_escape', parse_dates=['InvoiceDate'])
df1['Flag'] = 1
df2 = pd.read_csv(r"data/online_retail_II_2010_2011.csv", encoding='unicode_escape', parse_dates=['InvoiceDate'])
df2['Flag'] = 2
df = pd.concat([df1, df2])
df.reset_index(inplace=True, drop=True)
# df.head()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1067371 entries, 0 to 1067370
# Data columns (total 9 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   Invoice      1067371 non-null  object
#  1   StockCode    1067371 non-null  object
#  2   Description  1062989 non-null  object
#  3   Quantity     1067371 non-null  int64
#  4   InvoiceDate  1067371 non-null  datetime64[ns]
#  5   Price        1067371 non-null  float64
#  6   Customer ID  824364 non-null   float64
#  7   Country      1067371 non-null  object
#  8   Flag         1067371 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(2), object(4)
# memory usage: 73.3+ MB

# %% [markdown]
# Invoice must remain as str because of ones such as 'C489449'.
# Similarly, stockcode must remain as str.
# customerid is converted to Int64 which allows for the NaN values (int alone doesn't)

# %%
df.columns = df.columns.str.strip().str.lower()  # Strip leading/trailing whitespace and lowercase all column names
df.rename(columns={"customer id":"customerid"}, inplace=True)  # remove whitespace in customer ID as well
df.columns
# Out:
# Index(['invoice', 'stockcode', 'description', 'quantity', 'invoicedate',
#        'price', 'customerid', 'country', 'flag'],
#       dtype='object')

# %%
df['customerid'] = df['customerid'].astype('Int64')

# %%
df.isnull().sum()
# Out:
# invoice             0
# stockcode           0
# description      4382
# quantity            0
# invoicedate         0
# price               0
# customerid     243007
# country             0
# flag                0
# dtype: int64

# %%
df.boxplot(column=['quantity', 'price'])
# Out:
# <AxesSubplot:>

# %%
print(f"{len(df[df.quantity < 0]) / len(df) * 100:.2f}% of our quantities are negative") 
print(f"{len(df[df.price < 0]) / len(df) * 100:.2f}% of our prices are negative") 
print(f"{len(df[df.price == 0]) / len(df) * 100:.2f}% of our prices are equal to zero")
# Out:
# 2.15% of our quantities are negative
# 0.00% of our prices are negative
# 0.58% of our prices are equal to zero

# %% [markdown]
# Data has invoices prefaced with 'c' indicating that the order was cancelled.  Many of these are the places where the quantities are negative indicating a return.

# %%
canceldf = df[df.invoice.str.startswith('C')]  # store cancelled items

# %%
df = df[df.quantity > 0]  # Get rid of zero or negative quantity orders
df = df[df.price > 0]  # Get rid of zero or negative price orders

# %%
# Add revenue column for future analysis
df['revenue'] = df.quantity * df.price

# %%
def hasnumbers(inputstr):
    return any(char.isdigit() for char in inputstr)

nonum = df[df.stockcode.apply(hasnumbers) == False]  # See where the df has a stockcode that contains no numbers
nonum.stockcode.unique()
# Out:
# array(['POST', 'DOT', 'M', 'BANK CHARGES', 'PADS', 'ADJUST', 'm', 'D',
#        'S', 'DCGSSBOY', 'DCGSSGIRL', 'AMAZONFEE', 'B'], dtype=object)

# %% [markdown]
# Where the stockcode has no numbers, the charges are for things that are not actually sales of items.  As such we will make these a separate df 'nonum' and continue with our analysis using the 'actual' sales data.

# %%
df = df[df.stockcode.apply(hasnumbers) == True]

# %% [markdown]
# There exist 'test' items in our data as well, remove those.

# %%
df = df[~df.stockcode.str.contains('TEST')]

# %%
print(df.revenue.quantile([0, 0.25, 0.5, 0.75, 1]))
print(f"Only {len(df[df.revenue >= 5000])/len(df)*100}% of the df has revenue over 5000")
df[df.revenue >= 5000]
# Out:
# 0.00         0.06
# 0.25         3.90
# 0.50         9.96
# 0.75        17.70
# 1.00    168469.60
# Name: revenue, dtype: float64
# Only 0.0009640208151374405% of the df has revenue over 5000
#         invoice stockcode                          description  quantity  \
# 228042   511465    15044A                  PINK PAPER PARASOL       3500
# 379875   525968     84347  ROTATING SILVER ANGELS T-LIGHT HLDR      3120
# 432176   530715     84347  ROTATING SILVER ANGELS T-LIGHT HLDR      9360
# 461644   533027     22086      PAPER CHAIN KIT 50'S CHRISTMAS        835
# 578172   540815     21108   FAIRY CAKE FLANNEL ASSORTED COLOUR      3114
# 587080   541431     23166       MEDIUM CERAMIC TOP STORAGE JAR     74215
# 686007   550461     21108   FAIRY CAKE FLANNEL ASSORTED COLOUR      3114
# 748132   556444     22502       PICNIC BASKET WICKER 60 PIECES        60
# 873786   567423     23243  SET OF TEA COFFEE SUGAR TINS PANTRY      1412
# 1065882  581483     23843          PAPER CRAFT , LITTLE BIRDIE     80995
#
#                 invoicedate   price  customerid         country  flag  \
# 228042  2010-06-08 12:59:00    2.55       18008  United Kingdom     1
# 379875  2010-10-08 10:10:00    1.66       15838  United Kingdom     1
# 432176  2010-11-04 11:36:00    1.69       15838  United Kingdom     1
# 461644  2010-11-15 16:02:00    6.95        <NA>  United Kingdom     1
# 578172  2011-01-11 12:55:00    2.10       15749  United Kingdom     2
# 587080  2011-01-18 10:01:00    1.04       12346  United Kingdom     2
# 686007  2011-04-18 13:20:00    2.10       15749  United Kingdom     2
# 748132  2011-06-10 15:28:00  649.50       15098  United Kingdom     2
# 873786  2011-09-20 11:05:00    5.06       17450  United Kingdom     2
# 1065882 2011-12-09 09:15:00    2.08       16446  United Kingdom     2
#
#            revenue
# 228042     8925.00
# 379875     5179.20
# 432176    15818.40
# 461644     5803.25
# 578172     6539.40
# 587080    77183.60
# 686007     6539.40
# 748132    38970.00
# 873786     7144.72
# 1065882  168469.60

# %% [markdown]
# We can see that only a tiny amount of our data exists at or over this threshold of >= 5,000 sterling in revenue.  These may be real sales but their extreme values lead that to be suspect.  Even going down to a threshold of 2,500 sterling there are only 100 rows.  In any case, these over 5,000 seem so extreme compared to the rest of our data that we will exclude them from analysis.  Some very possible errors will remain for our sales where the revenue is extremely high but under 5,000 but we lack the data understanding to remove even more at this time.

# %%
df = df[df.revenue < 5000]

# %%
print(df.revenue.quantile([0, 0.25, 0.5, 0.75, 1]))
# Out:
# 0.00       0.06
# 0.25       3.90
# 0.50       9.96
# 0.75      17.70
# 1.00    4992.00
# Name: revenue, dtype: float64

# %%
df.to_csv(r"data/cleanOnlineRetail.csv")

# %% [markdown]
# # Business Questions

# %% [markdown]
# 1. What are our most commonly ordered items?
# 2. What is our total revenue?
# 3. When did we sell the most?
# 4. How do our sales trends look over time / by country?
# 5. Where do we sell the most?
# 6. Where is most profitable to sell?
# 7. What are our most profitable items?  Where are they sold the most?
# 8. How does our customer retention look?
# 9. What items are frequently bought together?

# %% [markdown]
# ## 1: What are our most commonly ordered items?
# Our most commonly ordered item is 85123A which is a white/cream colored T-light holder.

# %% [markdown]
# To be clear, this is speaking about the number of times an item is ordered rather than the number of the item within the order.  If item 'ABC123' was bought in two orders but at a quantity of 5,000 each time it would be lower than item 'DCF456' which was sold in three orders and a quantity of 1 per order.  Looking at the total quantity of items sold will be in business question 7.

# %%
df.head()
# Out:
#   invoice stockcode                          description  quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#           invoicedate  price  customerid         country  flag  revenue
# 0 2009-12-01 07:45:00   6.95       13085  United Kingdom     1     83.4
# 1 2009-12-01 07:45:00   6.75       13085  United Kingdom     1     81.0
# 2 2009-12-01 07:45:00   6.75       13085  United Kingdom     1     81.0
# 3 2009-12-01 07:45:00   2.10       13085  United Kingdom     1    100.8
# 4 2009-12-01 07:45:00   1.25       13085  United Kingdom     1     30.0

# %%
df.stockcode.value_counts()[:10].plot(kind='bar', title='Top 10 Products by Times Ordered');
plt.show()

# %%
df[df.stockcode=='85123A'].description.unique()
# Out:
# array(['WHITE HANGING HEART T-LIGHT HOLDER',
#        'CREAM HANGING HEART T-LIGHT HOLDER'], dtype=object)

# %% [markdown]
# ## 2: What is our total revenue?
# Our total revenue is 20,972,968.14 pound sterling.

# %%
print(f"Our total revenue is {df.revenue.sum():.2f} pound sterling")
# Out:
# Our total revenue is 19785450.67 pound sterling

# %% [markdown]
# ## 3: When did we sell the most?
# Near the starts and ends of the year.

# %% [markdown]
# We can see that in terms of number of sales, we peak at around the start/end of the year.  In terms of revenue, we can see our peaks are mostly around the end of the year in October or November.

# %%
ax = df.groupby("invoicedate").sum().revenue.plot()
plt.xlabel("Date")
plt.ylabel("Revenue")
plt.title("Sales over Time")
plt.show()
fig = ax.get_figure()
fig.savefig(r"data/imgs/salesOverTime.png")

# %%
ax = df.resample(rule='M', on='invoicedate')['revenue'].sum().plot();
plt.xlabel("Date")
plt.ylabel("Revenue")
plt.title("Revenue by Month")
plt.show();
fig = ax.get_figure()
fig.savefig(r"data/imgs/revByMonth.png")

# %% [markdown]
# ## 4: Sales trends over time and by country

# %% [markdown]
# See plots below

# %%
fig, axs = plt.subplots(2,1, figsize=(10,8), sharex=True)
# df.groupby("invoicedate").sum().revenue.plot(ax=axes[0])
# df.groupby("invoicedate").sum().quantity.plot(ax=axes[1])
axs[0].plot(df.groupby("invoicedate").sum().revenue, c='green');
axs[0].set_title("Revenue over Time")
axs[0].set_ylabel("Revenue")
axs[1].plot(df.groupby("invoicedate").sum().quantity, c='red');
axs[1].set_title('Quantity over Time')
axs[1].set_ylabel("Units Sold")
plt.show();

# %% [markdown]
# The above plots show that spikes in quantity sold do not directly translate to spikes in revenue.

# %% [markdown]
# There are a lot of results possible looking by country since we sell to such a wide market.  As such we will look only at the top 6 countries for plotting, but this can be changed for future analysis if it is called for.

# %%
top6Countries = df.groupby(["country"]).sum().revenue.nlargest(6).keys()  # Get top 5 countries' names, sorted by sum of revenues.
top6Countries
# Out:
# Index(['United Kingdom', 'EIRE', 'Netherlands', 'Germany', 'France',
#        'Australia'],
#       dtype='object', name='country')

# %%
def showCountrySales(countries, n=2, setShareY=False):
    """
    Small function to plot country revenue over time
    
    args:
        countries (list): List of contries to plot revenue over time for
        n (int): Skip every n'th xlabel for cleaner graphs.  Default skips every other one.
        setShareY (bool): Set if you want the y axes to be shared.  Off by default due to UK dominating in our example
    """
    fig, axs = plt.subplots((len(countries))//3, 3, figsize=(20,5), sharex=True, sharey=setShareY)
    grouped = df.groupby(["country","invoicedate"]).sum().revenue
    for country, ax in zip(countries, fig.axes):
        ax.plot(grouped[country]);
        plt.setp(ax.get_xticklabels()[::n], visible=False)
        ax.set_xlabel(country)
    fig = ax.get_figure()
    fig.savefig(r"data/imgs/salesByCountry.png")
    plt.show()

# %%
showCountrySales(top6Countries)

# %% [markdown]
# ## 5: Where do we sell the most?
# The UK by far.

# %% [markdown]
# In terms of both revenue generated and quantity sold, the UK dominates.  After that, we generate the most revenue in Ireland but sell more quantity in the Netherlands.

# %%
n=6
topNRevenue = df.groupby(["country"]).sum().revenue.nlargest(n)
topNQuantity = df.groupby(["country"]).sum().quantity.nlargest(n)
print(f"Our top {n} countries by revenue are: {topNRevenue.keys().values} selling {topNRevenue.values} streling respectively")
print(f"Our top {n} countries by quantity sold are {topNQuantity.keys().values} selling {topNQuantity.values} units respectively")
# Out:
# Our top 6 countries by revenue are: ['United Kingdom' 'EIRE' 'Netherlands' 'Germany' 'France' 'Australia'] selling [16898419.96   638933.63   549952.66   388829.75   317344.8    168484.66] streling respectively
# Our top 6 countries by quantity sold are ['United Kingdom' 'Netherlands' 'EIRE' 'France' 'Denmark' 'Germany'] selling [9191519  383722  340247  273938  237852  225878] units respectively

# %%
fig, axes = plt.subplots(1,2, figsize=(20,5))
axes[0].bar(topNRevenue.keys(), topNRevenue.values);
axes[0].set_title("Revenue by Country")
axes[0].set_ylabel("Revenue in Pound Sterling")
axes[1].bar(topNQuantity.keys(), topNQuantity.values);
axes[1].set_title("Quantity Sold by Country")
axes[1].set_ylabel("Units Sold")
fig.savefig(r"data/imgs/revAndQuantByCountry.png")
plt.show()

# %%
fig, axes = plt.subplots(1,2, figsize=(15,5))
axes[0].bar(topNRevenue.keys()[1:], topNRevenue.values[1:]);
axes[0].set_title("Revenue by Country")
axes[0].set_ylabel("Revenue in Pound Sterling")
axes[1].bar(topNQuantity.keys()[1:], topNQuantity.values[1:]);
axes[1].set_title("Quantity Sold by Country")
axes[1].set_ylabel("Units Sold")
fig.savefig(r"data/imgs/revAndQuantByCountryNOUK.png")
plt.show()

# %% [markdown]
# ## 6: Where is most profitable to sell?
# The UK dominates, followed by Ireland and perhaps the Netherlands

# %% [markdown]
# This ties in to our previous question. It is clear from question 5 that focusing on the UK is our bread and butter.  Past this though, Ireland and the Netherlands are our best bets.  Ireland seems to buy higher priced items at a slightly lower quantity than the Netherlands, but the Netherlands likes to buy al arger quantity of lower priced goods.  As such we could continue as we are within the UK but seek to expand within Ireland or the Netherlands.  Ireland makes the most sense due to proximity with our UK market and already largue revenue generation.  The slightly lower quantity sold means less than the higher revenue.

# %% [markdown]
# ## 7: What are our most profitable items?  Where are they sold the most?
# '85123A' is our best item by revenue generated and it is sold the most in the UK, followed distantly by Ireland.

# %% [markdown]
# This ties together questions 1 and 5.

# %%
n=15
topNItemRev = df.groupby(["stockcode"]).sum().revenue.nlargest(n)
topNItemQuant = df.groupby(["stockcode"]).sum().quantity.nlargest(n)
# print(f"Our top {n} items by revenue are: {topNItemRev.keys().values}\n" 
#       f"selling {topNItemRev.values} streling respectively"
#       f"Our top {n} items by quantity sold are {topNItemQuant.keys().values}\n"
#       f"selling {topNItemQuant.values} units respectively")

# %%
fig, axes = plt.subplots(1,2, figsize=(15,5))
axes[0].bar(topNItemRev.keys(), topNItemRev.values);
axes[0].set_title("Revenue by Item")
axes[0].set_ylabel("Revenue in Pound Sterling")
axes[0].tick_params('x', labelrotation=45);
axes[1].bar(topNItemQuant.keys(), topNItemQuant.values);
axes[1].set_title("Quantity Sold by Item")
axes[1].set_ylabel("Units Sold")
axes[1].tick_params('x', labelrotation=45);
fig.savefig(r"data/imgs/revQuantByItem.png")
plt.show();

# %%
df[df.stockcode == '22423'].description.unique()
# Out:
# array(['REGENCY CAKESTAND 3 TIER'], dtype=object)

# %%
df[df.stockcode == '84077'].description.unique()
# Out:
# array(['WORLD WAR 2 GLIDERS ASSTD DESIGNS'], dtype=object)

# %% [markdown]
# Our largest revenue generator is '22423' which is a cakestand, and our most commonly sold item is '84077' which are WWII glider designs.

# %% [markdown]
# Lets try to find our common items between top revenue generators and most sold items by quantity.

# %%
def findMatches(n=15):
    """
    Finds items which are both in the top 'n' for revenue and quantity sold

    Args:
        n (int): The number of top 'n' items to look through. Defaults to 15.
    """
    topNItemRevCodes = set(df.groupby(["stockcode"]).sum().revenue.nlargest(n).keys())
    topNItemQuantCodes = set(df.groupby(["stockcode"]).sum().quantity.nlargest(n).keys())
    if (topNItemRevCodes & topNItemQuantCodes):
        return(topNItemRevCodes & topNItemQuantCodes)
    else:
        print("No Common Stock Codes")

# %%
for stockCode in list(findMatches(n=15)):
    print(f"For item {stockCode}, {df.groupby(['stockcode']).sum().quantity[stockCode]} items were sold for a total of {df.groupby(['stockcode']).sum().revenue[stockCode]:.2f} pound Sterling")
# Out:
# For item 84879, 81809 items were sold for a total of 132187.92 pound Sterling
# For item 20725, 40942 items were sold for a total of 72292.85 pound Sterling
# For item 22197, 89898 items were sold for a total of 80920.64 pound Sterling
# For item 85123A, 96147 items were sold for a total of 263109.67 pound Sterling
# For item 85099B, 98349 items were sold for a total of 183454.83 pound Sterling

# %%
matchRev = df.groupby(["stockcode"]).sum().revenue[list(findMatches(n=15))].sort_values(ascending=False)
matchQuant = df.groupby(["stockcode"]).sum().quantity[list(findMatches(n=15))]

# %%
fig, axes = plt.subplots(2,1, figsize=(5,5), sharex=True)
axes[0].bar(matchRev.keys(), matchRev.values);
axes[0].set_title("Revenue by Item")
axes[0].set_ylabel("Revenue in Pound Sterling")
axes[0].tick_params('x', labelrotation=45);
axes[1].bar(matchQuant.keys(), matchQuant.values);
axes[1].set_title("Quantity Sold by Item")
axes[1].set_ylabel("Units Sold")
axes[1].tick_params('x', labelrotation=45);
fig.savefig(r"data/imgs/topItemRevQuant.png")
plt.show();

# %% [markdown]
# While we see a similar amount of '85123A' being sold as '85099B', the revenue for the former is much higher than for the latter.  From this we can see that focusing on '85123A' (our white/cream colored holder) is our best bet.  With that said, people clearly buy quite a few of our '85099B' (a jumbo spotted bag) so perhaps bundling this with other items would generate larger revenue.
#
# Overall it is hard to analyze the true profitability of our items as we have no data on the COGS.  If we had this, we could create a 'profit' column in the dataframe and do further analysis.  For now though, looking purely at the revenue, we should focus on '85123A' and perhaps bundle '85099B' with other items that we wish to promote.

# %%
df[df.stockcode == '85123A'].country.value_counts()[:10]
# Out:
# United Kingdom     5477
# EIRE                 87
# Netherlands          28
# Spain                20
# Cyprus               14
# Switzerland           9
# Italy                 7
# Channel Islands       7
# France                7
# Germany               6
# Name: country, dtype: int64

# %% [markdown]
# We sell the most of our best item in the UK, followed by Ireland.

# %% [markdown]
# ## 8: Customer Retention
# Existing customers are looking good, but we should incentivize new customers.

# %%
earliestdf = df.groupby('customerid').invoicedate.min().reset_index()
earliestdf.columns = ['customerid', 'earliestpurchasedate']
df2 = df.copy()
df2 = pd.merge(df2, earliestdf, on='customerid')
df2['custstatus'] = 'New'  # default each purchase to have the customer be 'new'
df2.loc[df2['invoicedate'] > df2['earliestpurchasedate'], 'custstatus'] = 'Existing'  # If the invoice is later than the earliest purchase, that is an order from an existing customer

revByStatus = df2.groupby(['invoicedate', 'custstatus'])['revenue'].sum().reset_index()  # New df to store grouped revenue by customer status
revNew = revByStatus[revByStatus.custstatus=='New'].resample(rule='M', on='invoicedate')['revenue'].sum().reset_index()  # Group by month and sum revenue within each month for new custs
revExisting = revByStatus[revByStatus.custstatus=='Existing'].resample(rule='M', on='invoicedate')['revenue'].sum().reset_index()  # as above but for existing custs

# %%
plt.figure(figsize=(10,5));
plt.plot(revNew.invoicedate, revNew.revenue, '-o', c='b', label='New');
plt.plot(revExisting.invoicedate, revExisting.revenue, '-o', c='r', label='Existing');
plt.title("Customer Retention");
plt.legend();
plt.ticklabel_format(style='plain', axis='y');
plt.ylabel("Number of Customers")
plt.show()

# %% [markdown]
# We can see that our number of existing customers seems to be on an okay - slightly positive - slope, but we see a slightly negative slope to our new customers over time.  This indicates that we are doing an okay job with our existing methods of customer retention, but we should perhaps put new efforts into our marketing for new customers.

# %% [markdown]
# ## 9: Items Frequently Bought Together

# %%
from mlxtend.frequent_patterns import apriori, association_rules
from mlxtend.preprocessing import TransactionEncoder

# %%
# Get all transactions with their relevant items
d = {}
for idx, row in df.iterrows():
    if row['invoice'] not in d:
        d[row['invoice']] = [row['stockcode']]
    else:
        d[row['invoice']].append(row['stockcode'])

# %%
# Turn the transactions dictionary into an apriori-friendly dataframe
ser = pd.Series({k: list(v) for k, v in d.items()}).str.join('|').str.get_dummies()
ser = ser.astype(bool)  # 0's and 1's may be depreciated in apriori soon, use bool instead

# %%
ser.head()
# Out:
#         10002  10002R  10080  10109  10120  10123C  10123G  10124A  10124G  \
# 489434  False   False  False  False  False   False   False   False   False
# 489435  False   False  False  False  False   False   False   False   False
# 489436  False   False  False  False  False   False   False   False   False
# 489437   True   False  False  False  False   False   False   False   False
# 489438  False   False  False  False  False   False   False   False   False
#
#         10125  ...  DCGS0075  DCGS0076  SP1002  gift_0001_10  gift_0001_20  \
# 489434  False  ...     False     False   False         False         False
# 489435  False  ...     False     False   False         False         False
# 489436  False  ...     False     False   False         False         False
# 489437  False  ...     False     False   False         False         False
# 489438  False  ...     False     False   False         False         False
#
#         gift_0001_30  gift_0001_40  gift_0001_50  gift_0001_70  gift_0001_80
# 489434         False         False         False         False         False
# 489435         False         False         False         False         False
# 489436         False         False         False         False         False
# 489437         False         False         False         False         False
# 489438         False         False         False         False         False
#
# [5 rows x 4901 columns]

# %%
apriori(ser, min_support=0.01)
# Out:
#        support                  itemsets
# 0     0.025074                      (17)
# 1     0.021684                      (23)
# 2     0.026137                      (24)
# 3     0.011360                      (33)
# 4     0.010601                      (60)
# ...        ...                       ...
# 1337  0.010703     (256, 257, 1581, 254)
# 1338  0.011487    (257, 1580, 1581, 254)
# 1339  0.011259    (256, 257, 1580, 1581)
# 1340  0.010601  (4272, 1626, 1607, 1223)
# 1341  0.010905  (1902, 1900, 1901, 1638)
#
# [1342 rows x 2 columns]

# %% [markdown]
# # Modeling and Forecasting
# Since almost all of our sales are in the UK we will focus our modeling and forecasting on the UK specifically.
# 1. Prophet
# 2. XGBoost
#     1. TimeSeriesSplit
#     2. HYPEROPT

# %% [markdown]
# ## Create Time Features
# First we must create some new time features for analysis.

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error

# %%
def makeTimeFeatures(df, datecol='invoicedate', useidx=False):
    df = df.copy()
    if useidx == False:
        df['dayofweek'] = df[datecol].dt.dayofweek
        df['month'] = df[datecol].dt.month
        df['quarter'] = df[datecol].dt.quarter
        df['year'] = df[datecol].dt.year
        df['dayofyear'] = df[datecol].dt.dayofyear
        df['dayofmonth'] = df[datecol].dt.day
        df['weekofyear'] = df[datecol].dt.weekofyear
        df['season'] = pd.cut(df[datecol].dt.month, [0, 3, 6, 9, 12], labels=['Winter', 'Spring', 'Summer', 'Fall'])  # Rough season cutoffs
    else:
        df['dayofweek'] = df.index.dayofweek
        df['month'] = df.index.month
        df['quarter'] = df.index.quarter
        df['year'] = df.index.year
        df['dayofyear'] = df.index.dayofyear
        df['dayofmonth'] = df.index.day
        df['weekofyear'] = df.index.weekofyear
        df['season'] = pd.cut(df.index.month, [0, 3, 6, 9, 12], labels=['Winter', 'Spring', 'Summer', 'Fall'])  # Rough season cutoffs
    return df

# %%
hourlydf = df[df.country == 'United Kingdom'][['invoicedate', 'revenue']].resample(rule='H', on='invoicedate').sum().reset_index()
timedf = makeTimeFeatures(hourlydf)
timedf['dayofweek'] = [x.strftime('%A') for x in timedf.invoicedate]  # Replace the day numbers with day names.  Could change in function, but this is mostly for the plot
timedf.head()
# Out:
# C:\Users\Zade\AppData\Local\Temp\ipykernel_6784\2333629205.py:10: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   df['weekofyear'] = df[datecol].dt.weekofyear
#           invoicedate  revenue dayofweek  month  quarter  year  dayofyear  \
# 0 2009-12-01 07:00:00   651.10   Tuesday     12        4  2009        335
# 1 2009-12-01 08:00:00     0.00   Tuesday     12        4  2009        335
# 2 2009-12-01 09:00:00  4597.93   Tuesday     12        4  2009        335
# 3 2009-12-01 10:00:00  4238.66   Tuesday     12        4  2009        335
# 4 2009-12-01 11:00:00  4598.41   Tuesday     12        4  2009        335
#
#    dayofmonth  weekofyear season
# 0           1          49   Fall
# 1           1          49   Fall
# 2           1          49   Fall
# 3           1          49   Fall
# 4           1          49   Fall

# %%
# Examine possible trends
fig, ax = plt.subplots(figsize=(8,8))
sns.boxplot(data=timedf, x='dayofweek', y='revenue', hue='season', ax=ax, showfliers=False);  # If we don't exclude outliers the plots are useless.
plt.show();

# %% [markdown]
# Can see a dirth of sales on Saturday and majorly reduced sales on Sunday.  It also seems that there is some seasonality within our data as we can see peaks in the Fall.  This is expected from our previous analysis where we saw large spikes in revenue near the ends of the years.

# %% [markdown]
# ## 1: Prophet Modeling
# We get an RMSE of around 2362

# %% [markdown]
# Prophet helps to confirm that there is hardly any slope in our revenue indicating that we are on a plateau in our earnings.  We also see that the hour of the day is very important to the revenue generated.

# %%
from prophet import Prophet

# %%
cutoffdate = '2011-06-8'  # Get a roughly 75-25 split in our data
train = timedf.loc[timedf.invoicedate <= cutoffdate].copy()
test = timedf.loc[timedf.invoicedate > cutoffdate].copy()
print(f"{len(train)/len(timedf)*100:.2f}% of our data is in the training with this cutoff date")
trainProph = train.rename(columns={'invoicedate':'ds', 'revenue':'y'})
testProph = test.rename(columns={'invoicedate':'ds', 'revenue':'y'})
# Out:
# 75.01% of our data is in the training with this cutoff date

# %%
model = Prophet()
model.fit(trainProph)
fcst = model.predict(testProph)
# Out:
# 15:40:21 - cmdstanpy - INFO - Chain [1] start processing
# 15:40:25 - cmdstanpy - INFO - Chain [1] done processing

# %%
fig, ax = plt.subplots()
fig = model.plot(fcst, ax=ax);
plt.show();

# %%
ax = (timedf.plot(x='invoicedate', y='revenue', title='Actual Vs. Forecast'));
fcst.plot(x='ds', y='yhat', ax=ax);
plt.show();

# %%
model.plot_components(fcst)

# %%
print(f"Our RMSE is: {np.sqrt(mean_squared_error(y_true=test.revenue, y_pred=fcst.yhat)):.3f}")
print(f"Our MAE is: {mean_absolute_error(y_true=test.revenue, y_pred=fcst.yhat):.3f}")
# print(f"Our MAPE is: {mean_absolute_percentage_error(test.revenue, fcst.yhat)}%")
# Out:
# Our RMSE is: 2362.054
# Our MAE is: 1021.341
# Our MAPE is: 1.5631727167914918e+18%

# %% [markdown]
# Quite awful.  Let's try again but with weekly data instead of hourly.

# %%
weeklydf = df[df.country == 'United Kingdom'][['invoicedate', 'revenue']].resample(rule='W', on='invoicedate').sum().reset_index()
weekdf = makeTimeFeatures(weeklydf)
weekdf['dayofweek'] = [x.strftime('%A') for x in weekdf.invoicedate]  # Replace the day numbers with day names.  Could change in function, but this is mostly for the plot
weekdf.head()
# Out:
# C:\Users\Zade\AppData\Local\Temp\ipykernel_6784\2333629205.py:10: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   df['weekofyear'] = df[datecol].dt.weekofyear
#   invoicedate    revenue dayofweek  month  quarter  year  dayofyear  \
# 0  2009-12-06  242679.06    Sunday     12        4  2009        340
# 1  2009-12-13  222429.73    Sunday     12        4  2009        347
# 2  2009-12-20  226897.91    Sunday     12        4  2009        354
# 3  2009-12-27   38255.85    Sunday     12        4  2009        361
# 4  2010-01-03       0.00    Sunday      1        1  2010          3
#
#    dayofmonth  weekofyear  season
# 0           6          49    Fall
# 1          13          50    Fall
# 2          20          51    Fall
# 3          27          52    Fall
# 4           3          53  Winter

# %%
cutoffdate = '2011-06-15'  # Get a roughly 75-25 split in our data
train2 = weekdf.loc[weekdf.invoicedate <= cutoffdate].copy()
test2 = weekdf.loc[weekdf.invoicedate > cutoffdate].copy()
print(f"{len(train2)/len(weekdf)*100:.2f}% of our data is in the training with this cutoff date")
trainProph2 = train2.rename(columns={'invoicedate':'ds', 'revenue':'y'})
testProph2 = test2.rename(columns={'invoicedate':'ds', 'revenue':'y'})
model2 = Prophet()
model2.fit(trainProph2)
fcst2 = model2.predict(testProph2)
fig, ax = plt.subplots()
fig = model2.plot(fcst2, ax=ax);
plt.show();
# Out:
# 15:45:16 - cmdstanpy - INFO - Chain [1] start processing
# 75.47% of our data is in the training with this cutoff date
# 15:45:16 - cmdstanpy - INFO - Chain [1] done processing

# %%
ax = (weekdf.plot(x='invoicedate', y='revenue', title='Actual Vs. Forecast'));
fcst2.plot(x='ds', y='yhat', ax=ax);
plt.show();

# %% [markdown]
# ## 2: XGBoost

# %% [markdown]
# ### 2.1: TimeSeriesSplit Modeling
# Our average RMSE is: 2467.136 with a minimum RMSE of 944.574

# %%
import xgboost as xgb
from xgboost import plot_importance
from sklearn.model_selection import TimeSeriesSplit
from sklearn.preprocessing import OneHotEncoder

# %%
tss = TimeSeriesSplit(n_splits=5, test_size=52, gap=24)

# %%
#Uncomment to view train/test splits by fold if needed

# fig, axes = plt.subplots(5,1, figsize=(10,10), sharex=True)
# fold=0
# for train_idx, test_idx in tss.split(nofulluk):
#     train = nofulluk.iloc[train_idx]
#     test = nofulluk.iloc[test_idx]
#     train.revenue.plot(ax=axes[fold], label='Training', title=f"Train/Test Split Fold {fold}");
#     test.revenue.plot(ax=axes[fold], label='Testing');
#     fold += 1
# plt.show();

# %%
timedf.head()
# Out:
#                      revenue dayofweek  month  quarter  year  dayofyear  \
# invoicedate
# 2009-12-01 07:00:00   651.10   Tuesday     12        4  2009        335
# 2009-12-01 08:00:00     0.00   Tuesday     12        4  2009        335
# 2009-12-01 09:00:00  4597.93   Tuesday     12        4  2009        335
# 2009-12-01 10:00:00  4238.66   Tuesday     12        4  2009        335
# 2009-12-01 11:00:00  4598.41   Tuesday     12        4  2009        335
#
#                      dayofmonth  weekofyear season  lag1  lag10  lag100
# invoicedate
# 2009-12-01 07:00:00           1          49   Fall   NaN    NaN     NaN
# 2009-12-01 08:00:00           1          49   Fall   NaN    NaN     NaN
# 2009-12-01 09:00:00           1          49   Fall   NaN    NaN     NaN
# 2009-12-01 10:00:00           1          49   Fall   NaN    NaN     NaN
# 2009-12-01 11:00:00           1          49   Fall   NaN    NaN     NaN

# %%
timedf = timedf.set_index('invoicedate').sort_index()
# timedf['lag1'] = timedf['revenue'].shift(freq='1D')
# timedf['lag10'] = timedf['revenue'].shift(freq='10D')
# timedf['lag100'] = timedf['revenue'].shift(freq='100D')
targets = timedf.revenue.to_dict()
timedf['lag1'] = (timedf.index - pd.Timedelta('1 days')).map(targets)
timedf['lag10'] = (timedf.index - pd.Timedelta('10 days')).map(targets)
timedf['lag100'] = (timedf.index - pd.Timedelta('100 days')).map(targets)

# %%
timedf.tail()
# Out:
#                       revenue dayofweek  month  quarter  year  dayofyear  \
# invoicedate
# 2011-12-09 08:00:00    963.04    Friday     12        4  2011        343
# 2011-12-09 09:00:00   3209.48    Friday     12        4  2011        343
# 2011-12-09 10:00:00  16448.50    Friday     12        4  2011        343
# 2011-12-09 11:00:00   1638.74    Friday     12        4  2011        343
# 2011-12-09 12:00:00   2757.40    Friday     12        4  2011        343
#
#                      dayofmonth  weekofyear season      lag1     lag10  \
# invoicedate
# 2011-12-09 08:00:00           9          49   Fall    482.28   1142.41
# 2011-12-09 09:00:00           9          49   Fall  16511.59   5032.14
# 2011-12-09 10:00:00           9          49   Fall   5424.21   6130.17
# 2011-12-09 11:00:00           9          49   Fall   7275.70  11905.01
# 2011-12-09 12:00:00           9          49   Fall   7810.56   6138.15
#
#                       lag100
# invoicedate
# 2011-12-09 08:00:00     0.00
# 2011-12-09 09:00:00  3053.96
# 2011-12-09 10:00:00  2562.40
# 2011-12-09 11:00:00   856.20
# 2011-12-09 12:00:00   602.40

# %% [markdown]
# Dummie encode our categorical variables for XGBoost.  Normalization isn't needed as we're using decision trees.

# %%
seasondummies = pd.get_dummies(timedf.season, prefix='season')
dayofweekdummies = pd.get_dummies(timedf.dayofweek, prefix='dow')
dummiedf = pd.concat([timedf, seasondummies, dayofweekdummies], axis=1)
dummiedf.drop(columns=['season', 'dayofweek'], inplace=True)
dummiedf.head()
# Out:
#                      revenue  month  quarter  year  dayofyear  dayofmonth  \
# invoicedate
# 2009-12-01 07:00:00   651.10     12        4  2009        335           1
# 2009-12-01 08:00:00     0.00     12        4  2009        335           1
# 2009-12-01 09:00:00  4597.93     12        4  2009        335           1
# 2009-12-01 10:00:00  4238.66     12        4  2009        335           1
# 2009-12-01 11:00:00  4598.41     12        4  2009        335           1
#
#                      weekofyear  lag1  lag10  lag100  ...  season_Spring  \
# invoicedate                                           ...
# 2009-12-01 07:00:00          49   NaN    NaN     NaN  ...              0
# 2009-12-01 08:00:00          49   NaN    NaN     NaN  ...              0
# 2009-12-01 09:00:00          49   NaN    NaN     NaN  ...              0
# 2009-12-01 10:00:00          49   NaN    NaN     NaN  ...              0
# 2009-12-01 11:00:00          49   NaN    NaN     NaN  ...              0
#
#                      season_Summer  season_Fall  dow_Friday  dow_Monday  \
# invoicedate
# 2009-12-01 07:00:00              0            1           0           0
# 2009-12-01 08:00:00              0            1           0           0
# 2009-12-01 09:00:00              0            1           0           0
# 2009-12-01 10:00:00              0            1           0           0
# 2009-12-01 11:00:00              0            1           0           0
#
#                      dow_Saturday  dow_Sunday  dow_Thursday  dow_Tuesday  \
# invoicedate
# 2009-12-01 07:00:00             0           0             0            1
# 2009-12-01 08:00:00             0           0             0            1
# 2009-12-01 09:00:00             0           0             0            1
# 2009-12-01 10:00:00             0           0             0            1
# 2009-12-01 11:00:00             0           0             0            1
#
#                      dow_Wednesday
# invoicedate
# 2009-12-01 07:00:00              0
# 2009-12-01 08:00:00              0
# 2009-12-01 09:00:00              0
# 2009-12-01 10:00:00              0
# 2009-12-01 11:00:00              0
#
# [5 rows x 21 columns]

# %%
fold = 0
preds = []
scores = []  # storing RMSE values
target = 'revenue'
MAPES = []
for train_idx, test_idx in tss.split(dummiedf):
    train = dummiedf.iloc[train_idx]
    test = dummiedf.iloc[test_idx]
    X_train = train.loc[:, train.columns != target]
    y_train = train[target]
    X_test = test.loc[:, test.columns != target]
    y_test = test[target]
    reg = xgb.XGBRegressor(booster='gbtree', early_stopping_rounds=50,
                           objective='reg:squarederror', max_depth=3)
    reg.fit(X_train, y_train, eval_set=[(X_train, y_train), (X_test, y_test)], verbose=100)
    y_pred = reg.predict(X_test)
    preds.append(y_pred)
    score = np.sqrt(mean_squared_error(y_test, y_pred))
    MAPE = mean_absolute_percentage_error(y_test, y_pred)
    MAPES.append(MAPE)
    scores.append(score)
# Out:
# [0]	validation_0-rmse:2279.55334	validation_1-rmse:3222.01944
# [99]	validation_0-rmse:1595.40601	validation_1-rmse:1851.15788
# [0]	validation_0-rmse:2283.59680	validation_1-rmse:2994.61905
# [56]	validation_0-rmse:1711.02321	validation_1-rmse:2342.62079
# [0]	validation_0-rmse:2284.59619	validation_1-rmse:1179.40816
# [53]	validation_0-rmse:1741.51691	validation_1-rmse:1514.94349
# [0]	validation_0-rmse:2284.84407	validation_1-rmse:4818.35078
# [63]	validation_0-rmse:1702.94238	validation_1-rmse:4242.84505
# [0]	validation_0-rmse:2293.38771	validation_1-rmse:5148.72180
# [60]	validation_0-rmse:1703.74841	validation_1-rmse:4422.66630

# %%
print(f"Our average RMSE is: {np.mean(scores):.3f} with a minimum RMSE of {np.min(scores):.3f}")
# print(f"Our average MAPE is {np.mean(MAPES):.3f} with a minimum MAPE of {np.min(MAPES):.3f} - though our XGBoost is scoring by RMSE")
# Out:
# Our average RMSE is: 2467.136 with a minimum RMSE of 944.574
# Our average MAPE is 482074934270411968.000 with a minimum MAPE of 158616862343722528.000 - though our XGBoost is scoring by RMSE

# %% [markdown]
# ### 2.2: HYPEROPT Modeling and Forecasting
# Our best model's RMSE is 2257.459
# We forecast out in to the future for one year, but since the trend is roughly linear, the plot is a roughly horizontal line with noise.

# %% [markdown]
# Here we will use HYPEROPT to do hyperparameter tuning on our XGBoost, but won't utilize tss.  Instead we'll have a set cutoffdate.  This is mostly because this will already take quite a long time to run with all of our tuning, and as such adding in more cross validation would make it wildly expensive.

# %%
from hyperopt import STATUS_OK, Trials, fmin, hp, tpe

# %%
# print(cutoffdate)  
target = 'revenue'
train = dummiedf[dummiedf.index <= cutoffdate]
test = dummiedf[dummiedf.index > cutoffdate]
print(len(train)/len(dummiedf)) #roughly 76-24 split here
X_train = train.loc[:, train.columns != target]
y_train = train[target]
X_test = test.loc[:, test.columns != target]
y_test = test[target]
# Out:
# 0.7595665424991535

# %%
space={'eta' : hp.uniform('eta', 0.01, 0.1),
       'gamma' : hp.quniform('gamma', 1, 9, 1),
       'max_depth' : hp.quniform('max_depth', 2, 5, 1),
       'min_child_weight' : hp.quniform('min_child_weight', 0, 10, 1),
       'colsample_bytree': hp.uniform('colsample_bytree', 0.1, 1),  # % of columns to use in each tree
       'n_estimators' : 200,
       'seed' : 543,
       'early_stopping_rounds' : 10
       }

# %%
def objective(space):
    clf=xgb.XGBRegressor(n_estimators=space['n_estimators'], max_depth=int(space['max_depth']), gamma=int(space['gamma']),
                            eta=space['eta'], min_child_weight=int(space['min_child_weight']), colsample_bytree=(space['colsample_bytree']))

    evaluation = [(X_train, y_train), (X_test, y_test)]
    
    clf.fit(X_train, y_train, eval_set=evaluation)
    pred = clf.predict(X_test)
    score = np.sqrt(mean_squared_error(y_test, pred))
    mape = mean_absolute_percentage_error(y_true=y_test, y_pred=pred)
    print(f"Score: {score}")
    return {'loss': score, 'mape': mape, 'status': STATUS_OK, 'model': clf}

# %%
trials = Trials()
best_hparams = fmin(fn = objective,
                    space = space,
                    algo = tpe.suggest,
                    max_evals = 50,
                    trials = trials)
# Out:
# [0]	validation_0-rmse:2391.27997	validation_1-rmse:2998.98526
# [1]	validation_0-rmse:2375.91418	validation_1-rmse:2980.01027
# [2]	validation_0-rmse:2349.11157	validation_1-rmse:2950.64417
# [3]	validation_0-rmse:2336.71445	validation_1-rmse:2935.74674
# [4]	validation_0-rmse:2300.47246	validation_1-rmse:2896.45882
# [5]	validation_0-rmse:2286.99222	validation_1-rmse:2881.01227
# [6]	validation_0-rmse:2275.21491	validation_1-rmse:2866.25697
# [7]	validation_0-rmse:2264.29253	validation_1-rmse:2854.63689
# [8]	validation_0-rmse:2242.83493	validation_1-rmse:2827.73365
# [9]	validation_0-rmse:2224.54490	validation_1-rmse:2805.68279
# [10]	validation_0-rmse:2218.02797	validation_1-rmse:2800.00485
# [11]	validation_0-rmse:2211.40340	validation_1-rmse:2791.55205
# [12]	validation_0-rmse:2205.83462	validation_1-rmse:2786.75072
# [13]	validation_0-rmse:2200.64843	validation_1-rmse:2782.31626
# [14]	validation_0-rmse:2195.69739	validation_1-rmse:2775.88301
# [15]	validation_0-rmse:2190.77208	validation_1-rmse:2770.53011
# [16]	validation_0-rmse:2183.92269	validation_1-rmse:2762.31560
# [17]	validation_0-rmse:2177.90595	validation_1-rmse:2755.41372
# [18]	validation_0-rmse:2171.88160	validation_1-rmse:2746.67179
# [19]	validation_0-rmse:2167.05340	validation_1-rmse:2741.13195
# [20]	validation_0-rmse:2152.63853	validation_1-rmse:2724.16760
# [21]	validation_0-rmse:2146.71527	validation_1-rmse:2718.59939
# [22]	validation_0-rmse:2130.90037	validation_1-rmse:2703.54638
# [23]	validation_0-rmse:2109.31881	validation_1-rmse:2681.03496
# [24]	validation_0-rmse:2087.66007	validation_1-rmse:2658.74076
# [25]	validation_0-rmse:2083.76540	validation_1-rmse:2654.64564
# [26]	validation_0-rmse:2072.43883	validation_1-rmse:2642.97346
# [27]	validation_0-rmse:2070.77532	validation_1-rmse:2640.93789
# [28]	validation_0-rmse:2067.50963	validation_1-rmse:2637.42640
# [29]	validation_0-rmse:2051.65233	validation_1-rmse:2622.04041
# [30]	validation_0-rmse:2050.34525	validation_1-rmse:2620.09511
# [31]	validation_0-rmse:2041.42932	validation_1-rmse:2610.28989
# [32]	validation_0-rmse:2040.19026	validation_1-rmse:2608.10810
# [33]	validation_0-rmse:2032.71474	validation_1-rmse:2599.66663
# [34]	validation_0-rmse:2023.55119	validation_1-rmse:2589.62758
# [35]	validation_0-rmse:2021.21254	validation_1-rmse:2587.38325
# [36]	validation_0-rmse:2020.26795	validation_1-rmse:2585.81509
# [37]	validation_0-rmse:2013.32472	validation_1-rmse:2578.61409
# [38]	validation_0-rmse:2007.52302	validation_1-rmse:2572.18179
# [39]	validation_0-rmse:2003.39719	validation_1-rmse:2567.26022
# [40]	validation_0-rmse:1994.48170	validation_1-rmse:2559.12765
# [41]	validation_0-rmse:1994.00898	validation_1-rmse:2558.34744
# [42]	validation_0-rmse:1988.53947	validation_1-rmse:2552.37582
# [43]	validation_0-rmse:1974.46901	validation_1-rmse:2540.72984
# [44]	validation_0-rmse:1965.98152	validation_1-rmse:2533.66524
# [45]	validation_0-rmse:1964.21308	validation_1-rmse:2532.60403
# [46]	validation_0-rmse:1962.42624	validation_1-rmse:2531.22577
# [47]	validation_0-rmse:1948.26316	validation_1-rmse:2519.23796
# [48]	validation_0-rmse:1947.81439	validation_1-rmse:2518.62977
# [49]	validation_0-rmse:1937.39882	validation_1-rmse:2509.61899
# [50]	validation_0-rmse:1925.18222	validation_1-rmse:2501.03132
# [51]	validation_0-rmse:1918.96844	validation_1-rmse:2496.49804
# [52]	validation_0-rmse:1918.40978	validation_1-rmse:2495.93546
# [53]	validation_0-rmse:1917.89646	validation_1-rmse:2495.57030
# [54]	validation_0-rmse:1912.24056	validation_1-rmse:2490.84005
# [55]	validation_0-rmse:1910.06999	validation_1-rmse:2488.93144
# [56]	validation_0-rmse:1905.95471	validation_1-rmse:2485.10063
# [57]	validation_0-rmse:1903.75121	validation_1-rmse:2482.10990
# [58]	validation_0-rmse:1903.10437	validation_1-rmse:2481.04379
# [59]	validation_0-rmse:1902.93665	validation_1-rmse:2480.74378
# [60]	validation_0-rmse:1893.84600	validation_1-rmse:2472.28343
# [61]	validation_0-rmse:1893.62875	validation_1-rmse:2471.90877
# [62]	validation_0-rmse:1888.49826	validation_1-rmse:2468.23028
# [63]	validation_0-rmse:1888.40007	validation_1-rmse:2467.99567
# [64]	validation_0-rmse:1888.20524	validation_1-rmse:2467.73244
# [65]	validation_0-rmse:1882.49468	validation_1-rmse:2464.00441
# [66]	validation_0-rmse:1881.39718	validation_1-rmse:2463.17263
# [67]	validation_0-rmse:1881.24643	validation_1-rmse:2462.87778
# [68]	validation_0-rmse:1872.56297	validation_1-rmse:2457.14438
# [69]	validation_0-rmse:1871.00900	validation_1-rmse:2455.82880
# [70]	validation_0-rmse:1870.14769	validation_1-rmse:2455.65768
# [71]	validation_0-rmse:1868.80777	validation_1-rmse:2455.45231
# [72]	validation_0-rmse:1867.89052	validation_1-rmse:2455.00093
# [73]	validation_0-rmse:1860.07003	validation_1-rmse:2448.66097
# [74]	validation_0-rmse:1859.63353	validation_1-rmse:2448.03296
# [75]	validation_0-rmse:1858.08167	validation_1-rmse:2445.91071
# [76]	validation_0-rmse:1857.59485	validation_1-rmse:2445.74617
# [77]	validation_0-rmse:1857.21032	validation_1-rmse:2445.62813
# [78]	validation_0-rmse:1856.57050	validation_1-rmse:2444.97758
# [79]	validation_0-rmse:1856.13265	validation_1-rmse:2444.82436
# [80]	validation_0-rmse:1846.90432	validation_1-rmse:2438.07918
# [81]	validation_0-rmse:1839.86889	validation_1-rmse:2432.96568
# [82]	validation_0-rmse:1834.22878	validation_1-rmse:2428.40786
# [83]	validation_0-rmse:1834.20528	validation_1-rmse:2428.40201
# [84]	validation_0-rmse:1833.51559	validation_1-rmse:2427.92218
# [85]	validation_0-rmse:1831.59531	validation_1-rmse:2425.55615
# [86]	validation_0-rmse:1831.10681	validation_1-rmse:2425.39406
# [87]	validation_0-rmse:1830.28410	validation_1-rmse:2425.30863
# [88]	validation_0-rmse:1827.21110	validation_1-rmse:2423.67615
# [89]	validation_0-rmse:1817.43390	validation_1-rmse:2413.46243
# [90]	validation_0-rmse:1817.41761	validation_1-rmse:2413.47041
# [91]	validation_0-rmse:1816.79328	validation_1-rmse:2413.59489
# [92]	validation_0-rmse:1815.51216	validation_1-rmse:2411.78215
# [93]	validation_0-rmse:1806.90319	validation_1-rmse:2403.63857
# [94]	validation_0-rmse:1803.15374	validation_1-rmse:2401.08675
# [95]	validation_0-rmse:1800.10313	validation_1-rmse:2399.65097
# [96]	validation_0-rmse:1800.09269	validation_1-rmse:2399.63750
# [97]	validation_0-rmse:1800.06298	validation_1-rmse:2399.61653
# [98]	validation_0-rmse:1799.64809	validation_1-rmse:2399.68550
# [99]	validation_0-rmse:1799.63898	validation_1-rmse:2399.67465
# [100]	validation_0-rmse:1799.62865	validation_1-rmse:2399.63955
# [101]	validation_0-rmse:1799.60447	validation_1-rmse:2399.60532
# [102]	validation_0-rmse:1799.53713	validation_1-rmse:2399.53043
# [103]	validation_0-rmse:1796.68873	validation_1-rmse:2397.52348
# [104]	validation_0-rmse:1796.48325	validation_1-rmse:2397.09675
# [105]	validation_0-rmse:1796.48129	validation_1-rmse:2397.09554
# [106]	validation_0-rmse:1796.47440	validation_1-rmse:2397.09248
# [107]	validation_0-rmse:1796.45442	validation_1-rmse:2397.05472
# [108]	validation_0-rmse:1796.24655	validation_1-rmse:2396.93468
# [109]	validation_0-rmse:1792.23261	validation_1-rmse:2393.85902
# [110]	validation_0-rmse:1791.85819	validation_1-rmse:2393.96029
# [111]	validation_0-rmse:1791.84182	validation_1-rmse:2393.99644
# [112]	validation_0-rmse:1788.58407	validation_1-rmse:2393.29005
# [113]	validation_0-rmse:1788.39898	validation_1-rmse:2393.12509
# [114]	validation_0-rmse:1784.86626	validation_1-rmse:2390.39238
# [115]	validation_0-rmse:1784.86097	validation_1-rmse:2390.40140
# [116]	validation_0-rmse:1784.84537	validation_1-rmse:2390.38337
# [117]	validation_0-rmse:1781.93858	validation_1-rmse:2389.14957
# [118]	validation_0-rmse:1781.76776	validation_1-rmse:2389.21848
# [119]	validation_0-rmse:1781.03027	validation_1-rmse:2388.73905
# [120]	validation_0-rmse:1780.64644	validation_1-rmse:2388.39454
# [121]	validation_0-rmse:1779.71717	validation_1-rmse:2387.29788
# [122]	validation_0-rmse:1779.70247	validation_1-rmse:2387.27986
# [123]	validation_0-rmse:1778.44944	validation_1-rmse:2385.72603
# [124]	validation_0-rmse:1778.30908	validation_1-rmse:2385.38707
# [125]	validation_0-rmse:1778.29753	validation_1-rmse:2385.42537
# [126]	validation_0-rmse:1777.53667	validation_1-rmse:2384.45143
# [127]	validation_0-rmse:1777.33225	validation_1-rmse:2384.16309
# [128]	validation_0-rmse:1777.11972	validation_1-rmse:2383.86250
# [129]	validation_0-rmse:1774.56694	validation_1-rmse:2382.73329
# [130]	validation_0-rmse:1768.48757	validation_1-rmse:2379.73402
# [131]	validation_0-rmse:1768.43305	validation_1-rmse:2379.65750
# [132]	validation_0-rmse:1763.03092	validation_1-rmse:2375.33352
# [133]	validation_0-rmse:1763.00935	validation_1-rmse:2375.34084
# [134]	validation_0-rmse:1762.62787	validation_1-rmse:2375.24767
# [135]	validation_0-rmse:1761.95128	validation_1-rmse:2374.26262
# [136]	validation_0-rmse:1757.93604	validation_1-rmse:2372.12161
# [137]	validation_0-rmse:1754.27948	validation_1-rmse:2370.56430
# [138]	validation_0-rmse:1754.27913	validation_1-rmse:2370.56731
# [139]	validation_0-rmse:1753.66942	validation_1-rmse:2369.73030
# [140]	validation_0-rmse:1753.64745	validation_1-rmse:2369.73832
# [141]	validation_0-rmse:1753.09642	validation_1-rmse:2368.99513
# [142]	validation_0-rmse:1753.03112	validation_1-rmse:2368.88855
# [143]	validation_0-rmse:1752.49259	validation_1-rmse:2368.24005
# [144]	validation_0-rmse:1749.31744	validation_1-rmse:2366.71869
# [145]	validation_0-rmse:1744.76625	validation_1-rmse:2364.74338
# [146]	validation_0-rmse:1744.76044	validation_1-rmse:2364.73836
# [147]	validation_0-rmse:1742.90273	validation_1-rmse:2363.40269
# [148]	validation_0-rmse:1740.56677	validation_1-rmse:2362.69856
# [149]	validation_0-rmse:1733.11556	validation_1-rmse:2354.98918
# [150]	validation_0-rmse:1733.11524	validation_1-rmse:2354.98980
# [151]	validation_0-rmse:1732.84747	validation_1-rmse:2354.95788
# [152]	validation_0-rmse:1730.54218	validation_1-rmse:2352.84640
# [153]	validation_0-rmse:1726.90220	validation_1-rmse:2351.71443
# [154]	validation_0-rmse:1722.26537	validation_1-rmse:2350.27738
# [155]	validation_0-rmse:1719.12470	validation_1-rmse:2348.90096
# [156]	validation_0-rmse:1719.05617	validation_1-rmse:2348.87709
# [157]	validation_0-rmse:1718.92095	validation_1-rmse:2348.84818
# [158]	validation_0-rmse:1715.22406	validation_1-rmse:2347.12770
# [159]	validation_0-rmse:1711.46085	validation_1-rmse:2345.83353
# [160]	validation_0-rmse:1711.15963	validation_1-rmse:2346.03552
# [161]	validation_0-rmse:1710.70751	validation_1-rmse:2345.26390
# [162]	validation_0-rmse:1708.83274	validation_1-rmse:2345.03387
# [163]	validation_0-rmse:1708.80971	validation_1-rmse:2345.02245
# [164]	validation_0-rmse:1708.58607	validation_1-rmse:2345.19369
# [165]	validation_0-rmse:1708.27577	validation_1-rmse:2344.99864
# [166]	validation_0-rmse:1708.07480	validation_1-rmse:2345.16438
# [167]	validation_0-rmse:1707.95377	validation_1-rmse:2345.10044
# [168]	validation_0-rmse:1707.84995	validation_1-rmse:2345.17826
# [169]	validation_0-rmse:1707.84503	validation_1-rmse:2345.20307
# [170]	validation_0-rmse:1707.57148	validation_1-rmse:2345.19771
# [171]	validation_0-rmse:1705.56375	validation_1-rmse:2344.76714
# [172]	validation_0-rmse:1705.53081	validation_1-rmse:2344.73051
# [173]	validation_0-rmse:1705.18169	validation_1-rmse:2344.56021
# [174]	validation_0-rmse:1702.58224	validation_1-rmse:2343.87179
# [175]	validation_0-rmse:1702.58189	validation_1-rmse:2343.87399
# [176]	validation_0-rmse:1700.23756	validation_1-rmse:2343.48095
# [177]	validation_0-rmse:1700.19464	validation_1-rmse:2343.41764
# [178]	validation_0-rmse:1700.09198	validation_1-rmse:2343.31317
# [179]	validation_0-rmse:1700.04951	validation_1-rmse:2343.14194
# [180]	validation_0-rmse:1697.11879	validation_1-rmse:2341.80011
# [181]	validation_0-rmse:1697.07252	validation_1-rmse:2341.76359
# [182]	validation_0-rmse:1695.54138	validation_1-rmse:2341.38764
# [183]	validation_0-rmse:1692.13735	validation_1-rmse:2339.76333
# [184]	validation_0-rmse:1691.63874	validation_1-rmse:2339.91078
# [185]	validation_0-rmse:1688.94939	validation_1-rmse:2340.31197
# [186]	validation_0-rmse:1688.88085	validation_1-rmse:2340.30914
# [187]	validation_0-rmse:1688.51491	validation_1-rmse:2339.64840
# [188]	validation_0-rmse:1688.42975	validation_1-rmse:2339.64471
# [189]	validation_0-rmse:1688.34569	validation_1-rmse:2339.62097
# [190]	validation_0-rmse:1688.31533	validation_1-rmse:2339.61536
# [191]	validation_0-rmse:1685.58573	validation_1-rmse:2339.27791
# [192]	validation_0-rmse:1685.27176	validation_1-rmse:2338.75754
# [193]	validation_0-rmse:1683.15210	validation_1-rmse:2338.82569
# [194]	validation_0-rmse:1681.88633	validation_1-rmse:2338.58997
# [195]	validation_0-rmse:1680.42433	validation_1-rmse:2338.40880
# [196]	validation_0-rmse:1680.24440	validation_1-rmse:2338.41321
# [197]	validation_0-rmse:1680.17275	validation_1-rmse:2338.41517
# [198]	validation_0-rmse:1679.32927	validation_1-rmse:2338.35663
# [199]	validation_0-rmse:1679.04055	validation_1-rmse:2338.00019
# Score: 2338.0001769899127
# [0]	validation_0-rmse:2357.10655	validation_1-rmse:2955.28621
# [1]	validation_0-rmse:2326.89279	validation_1-rmse:2917.88616
# [2]	validation_0-rmse:2283.81928	validation_1-rmse:2868.08820
# [3]	validation_0-rmse:2263.89774	validation_1-rmse:2843.54916
# [4]	validation_0-rmse:2204.81032	validation_1-rmse:2777.33155
# [5]	validation_0-rmse:2188.39804	validation_1-rmse:2756.40140
# [6]	validation_0-rmse:2151.50159	validation_1-rmse:2709.18555
# [7]	validation_0-rmse:2117.72128	validation_1-rmse:2662.32800
# [8]	validation_0-rmse:2078.74861	validation_1-rmse:2613.04761
# [9]	validation_0-rmse:2056.10621	validation_1-rmse:2584.74332
# [10]	validation_0-rmse:2050.20917	validation_1-rmse:2576.06685
# [11]	validation_0-rmse:2042.74143	validation_1-rmse:2568.24933
# [12]	validation_0-rmse:2028.90832	validation_1-rmse:2551.13124
# [13]	validation_0-rmse:2024.93325	validation_1-rmse:2545.10856
# [14]	validation_0-rmse:2011.02882	validation_1-rmse:2527.37268
# [15]	validation_0-rmse:1982.77463	validation_1-rmse:2495.03627
# [16]	validation_0-rmse:1955.81579	validation_1-rmse:2464.38727
# [17]	validation_0-rmse:1943.63190	validation_1-rmse:2446.42687
# [18]	validation_0-rmse:1938.58583	validation_1-rmse:2439.63864
# [19]	validation_0-rmse:1933.68282	validation_1-rmse:2433.55628
# [20]	validation_0-rmse:1925.74342	validation_1-rmse:2422.02112
# [21]	validation_0-rmse:1922.76427	validation_1-rmse:2419.68252
# [22]	validation_0-rmse:1914.61497	validation_1-rmse:2409.92563
# [23]	validation_0-rmse:1902.36482	validation_1-rmse:2395.97795
# [24]	validation_0-rmse:1888.64403	validation_1-rmse:2384.08584
# [25]	validation_0-rmse:1887.26160	validation_1-rmse:2382.89819
# [26]	validation_0-rmse:1883.29999	validation_1-rmse:2378.00707
# [27]	validation_0-rmse:1881.67308	validation_1-rmse:2375.95415
# [28]	validation_0-rmse:1880.26742	validation_1-rmse:2374.67286
# [29]	validation_0-rmse:1872.71201	validation_1-rmse:2367.19910
# [30]	validation_0-rmse:1872.30672	validation_1-rmse:2366.88741
# [31]	validation_0-rmse:1868.08093	validation_1-rmse:2361.47194
# [32]	validation_0-rmse:1867.84966	validation_1-rmse:2361.28416
# [33]	validation_0-rmse:1864.44141	validation_1-rmse:2358.62385
# [34]	validation_0-rmse:1861.82406	validation_1-rmse:2356.86884
# [35]	validation_0-rmse:1859.11944	validation_1-rmse:2353.18930
# [36]	validation_0-rmse:1857.08973	validation_1-rmse:2350.28309
# [37]	validation_0-rmse:1853.85137	validation_1-rmse:2345.28951
# [38]	validation_0-rmse:1851.41933	validation_1-rmse:2343.36119
# [39]	validation_0-rmse:1844.80462	validation_1-rmse:2333.05290
# [40]	validation_0-rmse:1842.19492	validation_1-rmse:2330.52795
# [41]	validation_0-rmse:1842.05219	validation_1-rmse:2330.40286
# [42]	validation_0-rmse:1836.63190	validation_1-rmse:2323.72674
# [43]	validation_0-rmse:1828.04443	validation_1-rmse:2315.09316
# [44]	validation_0-rmse:1825.99833	validation_1-rmse:2312.79411
# [45]	validation_0-rmse:1823.65829	validation_1-rmse:2310.77089
# [46]	validation_0-rmse:1823.04303	validation_1-rmse:2310.43726
# [47]	validation_0-rmse:1816.55017	validation_1-rmse:2307.40897
# [48]	validation_0-rmse:1816.05748	validation_1-rmse:2307.11650
# [49]	validation_0-rmse:1809.90526	validation_1-rmse:2300.52876
# [50]	validation_0-rmse:1804.34589	validation_1-rmse:2298.75520
# [51]	validation_0-rmse:1802.28756	validation_1-rmse:2296.84715
# [52]	validation_0-rmse:1801.49618	validation_1-rmse:2296.88996
# [53]	validation_0-rmse:1798.31979	validation_1-rmse:2295.41593
# [54]	validation_0-rmse:1796.92201	validation_1-rmse:2295.90457
# [55]	validation_0-rmse:1796.13558	validation_1-rmse:2295.28325
# [56]	validation_0-rmse:1795.34856	validation_1-rmse:2294.98210
# [57]	validation_0-rmse:1794.45012	validation_1-rmse:2293.65822
# [58]	validation_0-rmse:1790.51453	validation_1-rmse:2291.99243
# [59]	validation_0-rmse:1790.20270	validation_1-rmse:2291.92869
# [60]	validation_0-rmse:1786.41608	validation_1-rmse:2287.38722
# [61]	validation_0-rmse:1786.26420	validation_1-rmse:2287.33114
# [62]	validation_0-rmse:1784.18936	validation_1-rmse:2287.00116
# [63]	validation_0-rmse:1783.94571	validation_1-rmse:2287.06326
# [64]	validation_0-rmse:1783.25607	validation_1-rmse:2285.61245
# [65]	validation_0-rmse:1781.50906	validation_1-rmse:2285.37311
# [66]	validation_0-rmse:1781.27225	validation_1-rmse:2285.34358
# [67]	validation_0-rmse:1781.00484	validation_1-rmse:2285.30479
# [68]	validation_0-rmse:1777.57554	validation_1-rmse:2284.77989
# [69]	validation_0-rmse:1776.85133	validation_1-rmse:2283.47927
# [70]	validation_0-rmse:1775.64997	validation_1-rmse:2283.32020
# [71]	validation_0-rmse:1772.57190	validation_1-rmse:2283.15809
# [72]	validation_0-rmse:1772.35329	validation_1-rmse:2283.04968
# [73]	validation_0-rmse:1770.05145	validation_1-rmse:2281.30684
# [74]	validation_0-rmse:1767.81221	validation_1-rmse:2281.32773
# [75]	validation_0-rmse:1765.56140	validation_1-rmse:2278.06882
# [76]	validation_0-rmse:1764.72161	validation_1-rmse:2277.96099
# [77]	validation_0-rmse:1764.59857	validation_1-rmse:2277.94216
# [78]	validation_0-rmse:1764.03783	validation_1-rmse:2277.48810
# [79]	validation_0-rmse:1763.17573	validation_1-rmse:2277.17287
# [80]	validation_0-rmse:1760.94870	validation_1-rmse:2277.00732
# [81]	validation_0-rmse:1757.67714	validation_1-rmse:2274.56122
# [82]	validation_0-rmse:1756.10890	validation_1-rmse:2274.61725
# [83]	validation_0-rmse:1755.88235	validation_1-rmse:2274.10498
# [84]	validation_0-rmse:1755.39079	validation_1-rmse:2273.91498
# [85]	validation_0-rmse:1755.01585	validation_1-rmse:2273.70371
# [86]	validation_0-rmse:1752.10844	validation_1-rmse:2271.85637
# [87]	validation_0-rmse:1751.92511	validation_1-rmse:2271.83252
# [88]	validation_0-rmse:1750.47961	validation_1-rmse:2269.26078
# [89]	validation_0-rmse:1749.20012	validation_1-rmse:2269.81626
# [90]	validation_0-rmse:1747.14544	validation_1-rmse:2269.93595
# [91]	validation_0-rmse:1746.05473	validation_1-rmse:2270.62030
# [92]	validation_0-rmse:1745.89093	validation_1-rmse:2270.50653
# [93]	validation_0-rmse:1744.98632	validation_1-rmse:2271.13222
# [94]	validation_0-rmse:1744.47640	validation_1-rmse:2271.14426
# [95]	validation_0-rmse:1743.98896	validation_1-rmse:2271.05660
# [96]	validation_0-rmse:1743.03637	validation_1-rmse:2270.84315
# [97]	validation_0-rmse:1742.46433	validation_1-rmse:2270.74552
# [98]	validation_0-rmse:1742.30835	validation_1-rmse:2270.74655
# [99]	validation_0-rmse:1742.19101	validation_1-rmse:2270.73199
# [100]	validation_0-rmse:1741.65054	validation_1-rmse:2271.03813
# [101]	validation_0-rmse:1741.55381	validation_1-rmse:2271.06908
# [102]	validation_0-rmse:1741.25633	validation_1-rmse:2271.27980
# [103]	validation_0-rmse:1741.00618	validation_1-rmse:2271.12421
# [104]	validation_0-rmse:1740.61992	validation_1-rmse:2271.24410
# [105]	validation_0-rmse:1740.59090	validation_1-rmse:2271.28295
# [106]	validation_0-rmse:1739.67123	validation_1-rmse:2271.30537
# [107]	validation_0-rmse:1739.60437	validation_1-rmse:2271.31570
# [108]	validation_0-rmse:1738.42662	validation_1-rmse:2269.62306
# [109]	validation_0-rmse:1738.02873	validation_1-rmse:2269.39469
# [110]	validation_0-rmse:1737.92784	validation_1-rmse:2269.40825
# [111]	validation_0-rmse:1737.74650	validation_1-rmse:2269.48546
# [112]	validation_0-rmse:1737.41815	validation_1-rmse:2269.38850
# [113]	validation_0-rmse:1737.26801	validation_1-rmse:2269.47802
# [114]	validation_0-rmse:1736.63365	validation_1-rmse:2269.49497
# [115]	validation_0-rmse:1736.30636	validation_1-rmse:2269.54474
# [116]	validation_0-rmse:1735.15420	validation_1-rmse:2269.64788
# [117]	validation_0-rmse:1734.66779	validation_1-rmse:2269.88893
# [118]	validation_0-rmse:1733.22907	validation_1-rmse:2270.03721
# [119]	validation_0-rmse:1732.81307	validation_1-rmse:2269.03587
# [120]	validation_0-rmse:1732.55262	validation_1-rmse:2269.17969
# [121]	validation_0-rmse:1731.46421	validation_1-rmse:2268.16614
# [122]	validation_0-rmse:1731.36013	validation_1-rmse:2268.07573
# [123]	validation_0-rmse:1730.96266	validation_1-rmse:2268.16213
# [124]	validation_0-rmse:1730.68013	validation_1-rmse:2268.21329
# [125]	validation_0-rmse:1729.66964	validation_1-rmse:2268.25411
# [126]	validation_0-rmse:1729.38288	validation_1-rmse:2268.31288
# [127]	validation_0-rmse:1728.85654	validation_1-rmse:2268.31238
# [128]	validation_0-rmse:1728.50243	validation_1-rmse:2267.52924
# [129]	validation_0-rmse:1727.92452	validation_1-rmse:2267.19076
# [130]	validation_0-rmse:1726.98679	validation_1-rmse:2267.38350
# [131]	validation_0-rmse:1726.64400	validation_1-rmse:2267.42132
# [132]	validation_0-rmse:1726.13347	validation_1-rmse:2267.99611
# [133]	validation_0-rmse:1725.93644	validation_1-rmse:2267.99300
# [134]	validation_0-rmse:1725.71963	validation_1-rmse:2267.97254
# [135]	validation_0-rmse:1724.02368	validation_1-rmse:2266.02639
# [136]	validation_0-rmse:1723.50104	validation_1-rmse:2265.99339
# [137]	validation_0-rmse:1722.92595	validation_1-rmse:2266.71875
# [138]	validation_0-rmse:1722.67618	validation_1-rmse:2267.02155
# [139]	validation_0-rmse:1722.35389	validation_1-rmse:2267.23984
# [140]	validation_0-rmse:1721.77591	validation_1-rmse:2267.36066
# [141]	validation_0-rmse:1720.97228	validation_1-rmse:2266.95763
# [142]	validation_0-rmse:1720.83012	validation_1-rmse:2266.96904
# [143]	validation_0-rmse:1720.62124	validation_1-rmse:2266.89140
# [144]	validation_0-rmse:1719.82455	validation_1-rmse:2267.61746
# [145]	validation_0-rmse:1719.32391	validation_1-rmse:2267.81165
# [146]	validation_0-rmse:1718.96681	validation_1-rmse:2268.15547
# [147]	validation_0-rmse:1718.75189	validation_1-rmse:2268.05273
# [148]	validation_0-rmse:1718.02745	validation_1-rmse:2268.17230
# [149]	validation_0-rmse:1717.33358	validation_1-rmse:2268.92836
# [150]	validation_0-rmse:1716.50479	validation_1-rmse:2269.46279
# [151]	validation_0-rmse:1715.30364	validation_1-rmse:2269.54890
# [152]	validation_0-rmse:1715.16609	validation_1-rmse:2269.67740
# [153]	validation_0-rmse:1714.56193	validation_1-rmse:2270.43389
# [154]	validation_0-rmse:1714.03770	validation_1-rmse:2270.17088
# [155]	validation_0-rmse:1713.33377	validation_1-rmse:2270.95270
# [156]	validation_0-rmse:1712.77557	validation_1-rmse:2271.56807
# [157]	validation_0-rmse:1712.56937	validation_1-rmse:2271.46019
# [158]	validation_0-rmse:1712.13062	validation_1-rmse:2271.20665
# [159]	validation_0-rmse:1711.64687	validation_1-rmse:2271.94865
# [160]	validation_0-rmse:1711.32287	validation_1-rmse:2272.32393
# [161]	validation_0-rmse:1711.28023	validation_1-rmse:2272.27025
# [162]	validation_0-rmse:1710.85967	validation_1-rmse:2272.14769
# [163]	validation_0-rmse:1710.83735	validation_1-rmse:2272.19638
# [164]	validation_0-rmse:1710.67423	validation_1-rmse:2272.15109
# [165]	validation_0-rmse:1710.30792	validation_1-rmse:2271.85682
# [166]	validation_0-rmse:1710.11232	validation_1-rmse:2271.86339
# [167]	validation_0-rmse:1710.01311	validation_1-rmse:2271.83001
# [168]	validation_0-rmse:1709.59424	validation_1-rmse:2272.56506
# [169]	validation_0-rmse:1709.47864	validation_1-rmse:2272.56493
# [170]	validation_0-rmse:1708.73841	validation_1-rmse:2272.78980
# [171]	validation_0-rmse:1708.32647	validation_1-rmse:2272.64730
# [172]	validation_0-rmse:1708.26123	validation_1-rmse:2272.69980
# [173]	validation_0-rmse:1708.10690	validation_1-rmse:2272.69491
# [174]	validation_0-rmse:1707.67866	validation_1-rmse:2273.47684
# [175]	validation_0-rmse:1707.63049	validation_1-rmse:2273.58836
# [176]	validation_0-rmse:1707.00501	validation_1-rmse:2273.73518
# [177]	validation_0-rmse:1706.97774	validation_1-rmse:2273.69799
# [178]	validation_0-rmse:1706.45261	validation_1-rmse:2273.85400
# [179]	validation_0-rmse:1706.43630	validation_1-rmse:2273.76008
# [180]	validation_0-rmse:1706.25596	validation_1-rmse:2273.82157
# [181]	validation_0-rmse:1706.22974	validation_1-rmse:2273.77141
# [182]	validation_0-rmse:1705.28066	validation_1-rmse:2273.66339
# [183]	validation_0-rmse:1704.93946	validation_1-rmse:2274.34627
# [184]	validation_0-rmse:1704.32195	validation_1-rmse:2274.70184
# [185]	validation_0-rmse:1704.13947	validation_1-rmse:2274.78259
# [186]	validation_0-rmse:1703.82027	validation_1-rmse:2274.56354
# [187]	validation_0-rmse:1703.62627	validation_1-rmse:2274.46929
# [188]	validation_0-rmse:1703.60153	validation_1-rmse:2274.51416
# [189]	validation_0-rmse:1703.57758	validation_1-rmse:2274.48545
# [190]	validation_0-rmse:1703.20559	validation_1-rmse:2274.23674
# [191]	validation_0-rmse:1702.83926	validation_1-rmse:2274.98135
# [192]	validation_0-rmse:1702.49947	validation_1-rmse:2274.70992
# [193]	validation_0-rmse:1702.17899	validation_1-rmse:2275.33290
# [194]	validation_0-rmse:1702.04508	validation_1-rmse:2275.26795
# [195]	validation_0-rmse:1701.82376	validation_1-rmse:2275.14724
# [196]	validation_0-rmse:1701.69186	validation_1-rmse:2275.14310
# [197]	validation_0-rmse:1701.60045	validation_1-rmse:2275.20877
# [198]	validation_0-rmse:1700.47185	validation_1-rmse:2274.16386
# [199]	validation_0-rmse:1700.43506	validation_1-rmse:2274.24951
# Score: 2274.249490962136
# [0]	validation_0-rmse:2384.53832	validation_1-rmse:2988.46103
# [1]	validation_0-rmse:2354.36717	validation_1-rmse:2952.27530
# [2]	validation_0-rmse:2315.99397	validation_1-rmse:2909.04922
# [3]	validation_0-rmse:2276.59997	validation_1-rmse:2862.10341
# [4]	validation_0-rmse:2240.31034	validation_1-rmse:2818.44607
# [5]	validation_0-rmse:2206.66645	validation_1-rmse:2780.34226
# [6]	validation_0-rmse:2181.40977	validation_1-rmse:2747.91698
# [7]	validation_0-rmse:2150.73649	validation_1-rmse:2713.39571
# [8]	validation_0-rmse:2125.17279	validation_1-rmse:2683.52316
# [9]	validation_0-rmse:2102.69541	validation_1-rmse:2653.93499
# [10]	validation_0-rmse:2079.24813	validation_1-rmse:2627.31187
# [11]	validation_0-rmse:2070.74229	validation_1-rmse:2616.25986
# [12]	validation_0-rmse:2052.22116	validation_1-rmse:2591.11339
# [13]	validation_0-rmse:2045.34378	validation_1-rmse:2582.71255
# [14]	validation_0-rmse:2028.27530	validation_1-rmse:2561.46883
# [15]	validation_0-rmse:2010.61774	validation_1-rmse:2541.19009
# [16]	validation_0-rmse:1994.56310	validation_1-rmse:2522.66263
# [17]	validation_0-rmse:1981.12148	validation_1-rmse:2505.50831
# [18]	validation_0-rmse:1969.88674	validation_1-rmse:2491.44403
# [19]	validation_0-rmse:1964.37176	validation_1-rmse:2483.66463
# [20]	validation_0-rmse:1952.03182	validation_1-rmse:2471.13412
# [21]	validation_0-rmse:1940.33370	validation_1-rmse:2456.09050
# [22]	validation_0-rmse:1931.84652	validation_1-rmse:2444.34281
# [23]	validation_0-rmse:1921.79264	validation_1-rmse:2432.73683
# [24]	validation_0-rmse:1911.92126	validation_1-rmse:2421.89927
# [25]	validation_0-rmse:1903.01513	validation_1-rmse:2411.29299
# [26]	validation_0-rmse:1896.61467	validation_1-rmse:2402.04329
# [27]	validation_0-rmse:1889.04527	validation_1-rmse:2393.70046
# [28]	validation_0-rmse:1883.22538	validation_1-rmse:2386.06686
# [29]	validation_0-rmse:1875.75204	validation_1-rmse:2378.32782
# [30]	validation_0-rmse:1871.35603	validation_1-rmse:2371.36761
# [31]	validation_0-rmse:1866.31134	validation_1-rmse:2363.61719
# [32]	validation_0-rmse:1859.49538	validation_1-rmse:2356.99896
# [33]	validation_0-rmse:1853.49874	validation_1-rmse:2352.33938
# [34]	validation_0-rmse:1849.88125	validation_1-rmse:2348.28325
# [35]	validation_0-rmse:1844.17672	validation_1-rmse:2340.92922
# [36]	validation_0-rmse:1838.62064	validation_1-rmse:2335.37229
# [37]	validation_0-rmse:1835.06382	validation_1-rmse:2330.47990
# [38]	validation_0-rmse:1830.65631	validation_1-rmse:2327.24401
# [39]	validation_0-rmse:1826.29174	validation_1-rmse:2321.50208
# [40]	validation_0-rmse:1823.54230	validation_1-rmse:2318.10956
# [41]	validation_0-rmse:1819.47093	validation_1-rmse:2314.58059
# [42]	validation_0-rmse:1817.15326	validation_1-rmse:2310.93017
# [43]	validation_0-rmse:1813.17941	validation_1-rmse:2308.24009
# [44]	validation_0-rmse:1811.09409	validation_1-rmse:2307.39869
# [45]	validation_0-rmse:1808.98686	validation_1-rmse:2305.34128
# [46]	validation_0-rmse:1806.92944	validation_1-rmse:2302.79620
# [47]	validation_0-rmse:1803.88248	validation_1-rmse:2301.05042
# [48]	validation_0-rmse:1800.84854	validation_1-rmse:2298.67701
# [49]	validation_0-rmse:1798.17973	validation_1-rmse:2296.17252
# [50]	validation_0-rmse:1795.69443	validation_1-rmse:2293.89928
# [51]	validation_0-rmse:1793.69213	validation_1-rmse:2291.53916
# [52]	validation_0-rmse:1792.39340	validation_1-rmse:2290.05734
# [53]	validation_0-rmse:1790.24169	validation_1-rmse:2289.03928
# [54]	validation_0-rmse:1788.53289	validation_1-rmse:2287.40776
# [55]	validation_0-rmse:1787.07982	validation_1-rmse:2286.93643
# [56]	validation_0-rmse:1784.97825	validation_1-rmse:2285.88887
# [57]	validation_0-rmse:1783.11678	validation_1-rmse:2284.03629
# [58]	validation_0-rmse:1781.31647	validation_1-rmse:2283.20633
# [59]	validation_0-rmse:1779.72798	validation_1-rmse:2281.58774
# [60]	validation_0-rmse:1777.94410	validation_1-rmse:2279.20888
# [61]	validation_0-rmse:1776.83258	validation_1-rmse:2277.47668
# [62]	validation_0-rmse:1775.30393	validation_1-rmse:2277.24384
# [63]	validation_0-rmse:1774.50322	validation_1-rmse:2276.35030
# [64]	validation_0-rmse:1773.35353	validation_1-rmse:2274.74562
# [65]	validation_0-rmse:1771.64937	validation_1-rmse:2274.13034
# [66]	validation_0-rmse:1771.05588	validation_1-rmse:2273.97628
# [67]	validation_0-rmse:1770.05092	validation_1-rmse:2272.93505
# [68]	validation_0-rmse:1768.43378	validation_1-rmse:2272.71293
# [69]	validation_0-rmse:1766.70415	validation_1-rmse:2272.39732
# [70]	validation_0-rmse:1765.43912	validation_1-rmse:2271.48354
# [71]	validation_0-rmse:1764.07891	validation_1-rmse:2271.60500
# [72]	validation_0-rmse:1762.81988	validation_1-rmse:2271.63290
# [73]	validation_0-rmse:1761.32392	validation_1-rmse:2271.55677
# [74]	validation_0-rmse:1760.32479	validation_1-rmse:2270.77619
# [75]	validation_0-rmse:1759.46862	validation_1-rmse:2269.92793
# [76]	validation_0-rmse:1758.69191	validation_1-rmse:2268.91672
# [77]	validation_0-rmse:1758.22024	validation_1-rmse:2268.66536
# [78]	validation_0-rmse:1756.97049	validation_1-rmse:2268.56729
# [79]	validation_0-rmse:1755.90048	validation_1-rmse:2268.68650
# [80]	validation_0-rmse:1754.91940	validation_1-rmse:2268.95823
# [81]	validation_0-rmse:1753.76419	validation_1-rmse:2269.07663
# [82]	validation_0-rmse:1752.66698	validation_1-rmse:2268.47849
# [83]	validation_0-rmse:1752.07062	validation_1-rmse:2268.43808
# [84]	validation_0-rmse:1751.33094	validation_1-rmse:2268.46946
# [85]	validation_0-rmse:1750.07959	validation_1-rmse:2267.09071
# [86]	validation_0-rmse:1749.26369	validation_1-rmse:2267.35067
# [87]	validation_0-rmse:1748.65440	validation_1-rmse:2266.61813
# [88]	validation_0-rmse:1747.47520	validation_1-rmse:2266.23528
# [89]	validation_0-rmse:1746.47481	validation_1-rmse:2265.98088
# [90]	validation_0-rmse:1745.47810	validation_1-rmse:2265.52687
# [91]	validation_0-rmse:1744.64738	validation_1-rmse:2265.37422
# [92]	validation_0-rmse:1743.94392	validation_1-rmse:2265.06926
# [93]	validation_0-rmse:1743.04707	validation_1-rmse:2265.40327
# [94]	validation_0-rmse:1742.37028	validation_1-rmse:2265.47572
# [95]	validation_0-rmse:1741.89177	validation_1-rmse:2264.93235
# [96]	validation_0-rmse:1741.04236	validation_1-rmse:2264.54354
# [97]	validation_0-rmse:1740.55630	validation_1-rmse:2263.73064
# [98]	validation_0-rmse:1739.87108	validation_1-rmse:2263.64482
# [99]	validation_0-rmse:1739.18348	validation_1-rmse:2263.64248
# [100]	validation_0-rmse:1738.78567	validation_1-rmse:2263.42809
# [101]	validation_0-rmse:1738.21925	validation_1-rmse:2262.88992
# [102]	validation_0-rmse:1737.79035	validation_1-rmse:2262.74546
# [103]	validation_0-rmse:1737.50419	validation_1-rmse:2262.78566
# [104]	validation_0-rmse:1737.09208	validation_1-rmse:2262.33759
# [105]	validation_0-rmse:1736.57480	validation_1-rmse:2262.34503
# [106]	validation_0-rmse:1735.95342	validation_1-rmse:2262.30419
# [107]	validation_0-rmse:1734.12850	validation_1-rmse:2262.58535
# [108]	validation_0-rmse:1733.52069	validation_1-rmse:2262.20419
# [109]	validation_0-rmse:1733.22691	validation_1-rmse:2262.08795
# [110]	validation_0-rmse:1732.30002	validation_1-rmse:2262.37473
# [111]	validation_0-rmse:1732.02410	validation_1-rmse:2261.85188
# [112]	validation_0-rmse:1730.35828	validation_1-rmse:2262.47854
# [113]	validation_0-rmse:1729.80699	validation_1-rmse:2262.44854
# [114]	validation_0-rmse:1729.53157	validation_1-rmse:2262.37832
# [115]	validation_0-rmse:1728.63376	validation_1-rmse:2262.27446
# [116]	validation_0-rmse:1727.82050	validation_1-rmse:2261.42199
# [117]	validation_0-rmse:1727.31641	validation_1-rmse:2261.42501
# [118]	validation_0-rmse:1726.43822	validation_1-rmse:2261.94702
# [119]	validation_0-rmse:1725.93028	validation_1-rmse:2261.47994
# [120]	validation_0-rmse:1725.09611	validation_1-rmse:2261.95590
# [121]	validation_0-rmse:1724.62941	validation_1-rmse:2261.96193
# [122]	validation_0-rmse:1724.22785	validation_1-rmse:2261.88640
# [123]	validation_0-rmse:1723.44108	validation_1-rmse:2262.41824
# [124]	validation_0-rmse:1723.18673	validation_1-rmse:2262.41947
# [125]	validation_0-rmse:1722.95951	validation_1-rmse:2262.49821
# [126]	validation_0-rmse:1722.06286	validation_1-rmse:2262.88825
# [127]	validation_0-rmse:1721.79787	validation_1-rmse:2262.70065
# [128]	validation_0-rmse:1721.47459	validation_1-rmse:2262.76321
# [129]	validation_0-rmse:1720.84627	validation_1-rmse:2263.00887
# [130]	validation_0-rmse:1719.89072	validation_1-rmse:2262.99947
# [131]	validation_0-rmse:1719.54775	validation_1-rmse:2263.02054
# [132]	validation_0-rmse:1719.31517	validation_1-rmse:2262.97457
# [133]	validation_0-rmse:1719.05217	validation_1-rmse:2263.01262
# [134]	validation_0-rmse:1718.80351	validation_1-rmse:2263.07555
# [135]	validation_0-rmse:1718.56979	validation_1-rmse:2263.01899
# [136]	validation_0-rmse:1717.83912	validation_1-rmse:2263.50174
# [137]	validation_0-rmse:1717.43442	validation_1-rmse:2263.57291
# [138]	validation_0-rmse:1716.06333	validation_1-rmse:2262.96811
# [139]	validation_0-rmse:1715.73240	validation_1-rmse:2263.01669
# [140]	validation_0-rmse:1715.52217	validation_1-rmse:2263.01113
# [141]	validation_0-rmse:1715.16869	validation_1-rmse:2263.18757
# [142]	validation_0-rmse:1714.66185	validation_1-rmse:2262.48008
# [143]	validation_0-rmse:1714.20844	validation_1-rmse:2262.86737
# [144]	validation_0-rmse:1713.79379	validation_1-rmse:2263.29367
# [145]	validation_0-rmse:1713.00549	validation_1-rmse:2263.24918
# [146]	validation_0-rmse:1712.54350	validation_1-rmse:2263.15610
# [147]	validation_0-rmse:1712.36023	validation_1-rmse:2263.19188
# [148]	validation_0-rmse:1711.99218	validation_1-rmse:2263.15644
# [149]	validation_0-rmse:1711.73533	validation_1-rmse:2262.98886
# [150]	validation_0-rmse:1711.21624	validation_1-rmse:2263.09963
# [151]	validation_0-rmse:1710.63090	validation_1-rmse:2262.69603
# [152]	validation_0-rmse:1709.88542	validation_1-rmse:2263.07123
# [153]	validation_0-rmse:1709.18010	validation_1-rmse:2262.96236
# [154]	validation_0-rmse:1708.77012	validation_1-rmse:2263.03403
# [155]	validation_0-rmse:1708.67633	validation_1-rmse:2263.12164
# [156]	validation_0-rmse:1708.28007	validation_1-rmse:2263.46538
# [157]	validation_0-rmse:1707.96485	validation_1-rmse:2263.49351
# [158]	validation_0-rmse:1707.59710	validation_1-rmse:2263.83922
# [159]	validation_0-rmse:1707.11396	validation_1-rmse:2263.72356
# [160]	validation_0-rmse:1706.69142	validation_1-rmse:2264.07459
# [161]	validation_0-rmse:1706.57550	validation_1-rmse:2264.13989
# [162]	validation_0-rmse:1705.91688	validation_1-rmse:2263.92063
# [163]	validation_0-rmse:1705.22712	validation_1-rmse:2263.93293
# [164]	validation_0-rmse:1704.54390	validation_1-rmse:2264.01193
# [165]	validation_0-rmse:1704.28495	validation_1-rmse:2263.90765
# [166]	validation_0-rmse:1703.82855	validation_1-rmse:2263.62433
# [167]	validation_0-rmse:1703.52773	validation_1-rmse:2263.59139
# [168]	validation_0-rmse:1703.19695	validation_1-rmse:2263.93021
# [169]	validation_0-rmse:1702.88797	validation_1-rmse:2264.30896
# [170]	validation_0-rmse:1702.50616	validation_1-rmse:2264.69653
# [171]	validation_0-rmse:1702.21424	validation_1-rmse:2264.65163
# [172]	validation_0-rmse:1701.41387	validation_1-rmse:2262.95037
# [173]	validation_0-rmse:1701.12536	validation_1-rmse:2263.30524
# [174]	validation_0-rmse:1700.79866	validation_1-rmse:2263.16335
# [175]	validation_0-rmse:1700.53729	validation_1-rmse:2263.09152
# [176]	validation_0-rmse:1700.37215	validation_1-rmse:2263.15483
# [177]	validation_0-rmse:1700.26128	validation_1-rmse:2263.15820
# [178]	validation_0-rmse:1699.94008	validation_1-rmse:2263.30323
# [179]	validation_0-rmse:1699.76943	validation_1-rmse:2262.95948
# [180]	validation_0-rmse:1698.97193	validation_1-rmse:2263.79939
# [181]	validation_0-rmse:1698.77414	validation_1-rmse:2263.59388
# [182]	validation_0-rmse:1698.42468	validation_1-rmse:2264.04679
# [183]	validation_0-rmse:1698.10512	validation_1-rmse:2264.51769
# [184]	validation_0-rmse:1697.67857	validation_1-rmse:2264.01979
# [185]	validation_0-rmse:1697.39277	validation_1-rmse:2263.84897
# [186]	validation_0-rmse:1695.92208	validation_1-rmse:2263.31957
# [187]	validation_0-rmse:1694.80519	validation_1-rmse:2262.79917
# [188]	validation_0-rmse:1694.43296	validation_1-rmse:2262.83852
# [189]	validation_0-rmse:1694.20980	validation_1-rmse:2263.23627
# [190]	validation_0-rmse:1693.86192	validation_1-rmse:2263.16345
# [191]	validation_0-rmse:1693.64537	validation_1-rmse:2263.58028
# [192]	validation_0-rmse:1693.23747	validation_1-rmse:2263.66549
# [193]	validation_0-rmse:1693.02629	validation_1-rmse:2263.99143
# [194]	validation_0-rmse:1692.87945	validation_1-rmse:2263.92421
# [195]	validation_0-rmse:1692.21857	validation_1-rmse:2264.42996
# [196]	validation_0-rmse:1692.05737	validation_1-rmse:2264.36181
# [197]	validation_0-rmse:1691.67168	validation_1-rmse:2264.47186
# [198]	validation_0-rmse:1691.46030	validation_1-rmse:2264.58317
# [199]	validation_0-rmse:1691.25489	validation_1-rmse:2264.88856
# Score: 2264.8885522621226
# [0]	validation_0-rmse:2344.99677	validation_1-rmse:2941.68708
# [1]	validation_0-rmse:2274.66407	validation_1-rmse:2863.02044
# [2]	validation_0-rmse:2206.63596	validation_1-rmse:2781.27784
# [3]	validation_0-rmse:2148.35518	validation_1-rmse:2711.60771
# [4]	validation_0-rmse:2098.76357	validation_1-rmse:2656.74688
# [5]	validation_0-rmse:2052.37141	validation_1-rmse:2602.89238
# [6]	validation_0-rmse:2014.98996	validation_1-rmse:2561.71550
# [7]	validation_0-rmse:1979.67072	validation_1-rmse:2519.41284
# [8]	validation_0-rmse:1949.66085	validation_1-rmse:2484.83030
# [9]	validation_0-rmse:1924.00301	validation_1-rmse:2454.34983
# [10]	validation_0-rmse:1903.97059	validation_1-rmse:2430.73816
# [11]	validation_0-rmse:1882.12467	validation_1-rmse:2412.29114
# [12]	validation_0-rmse:1864.03699	validation_1-rmse:2392.00871
# [13]	validation_0-rmse:1849.78800	validation_1-rmse:2379.51208
# [14]	validation_0-rmse:1837.20577	validation_1-rmse:2368.48814
# [15]	validation_0-rmse:1824.45478	validation_1-rmse:2354.96639
# [16]	validation_0-rmse:1806.79509	validation_1-rmse:2338.54557
# [17]	validation_0-rmse:1795.28706	validation_1-rmse:2330.58047
# [18]	validation_0-rmse:1784.03386	validation_1-rmse:2317.66036
# [19]	validation_0-rmse:1775.84315	validation_1-rmse:2308.39463
# [20]	validation_0-rmse:1767.47570	validation_1-rmse:2301.24222
# [21]	validation_0-rmse:1761.40203	validation_1-rmse:2296.48071
# [22]	validation_0-rmse:1755.30601	validation_1-rmse:2288.58509
# [23]	validation_0-rmse:1745.62331	validation_1-rmse:2283.70938
# [24]	validation_0-rmse:1739.30051	validation_1-rmse:2280.33597
# [25]	validation_0-rmse:1734.85013	validation_1-rmse:2276.46456
# [26]	validation_0-rmse:1730.95147	validation_1-rmse:2273.95768
# [27]	validation_0-rmse:1727.12091	validation_1-rmse:2272.75772
# [28]	validation_0-rmse:1719.52612	validation_1-rmse:2270.25635
# [29]	validation_0-rmse:1714.50443	validation_1-rmse:2268.15865
# [30]	validation_0-rmse:1707.97498	validation_1-rmse:2267.71069
# [31]	validation_0-rmse:1704.75932	validation_1-rmse:2266.23647
# [32]	validation_0-rmse:1702.27128	validation_1-rmse:2266.46576
# [33]	validation_0-rmse:1696.17673	validation_1-rmse:2264.12034
# [34]	validation_0-rmse:1692.16276	validation_1-rmse:2261.50917
# ...
# [7]	validation_0-rmse:2178.67457	validation_1-rmse:2747.27613
# [8]	validation_0-rmse:2141.40977	validation_1-rmse:2700.42605
# [9]	validation_0-rmse:2121.22291	validation_1-rmse:2675.39217
# [10]	validation_0-rmse:2114.16168	validation_1-rmse:2665.61347
# [11]	validation_0-rmse:2106.44785	validation_1-rmse:2656.56858
# [12]	validation_0-rmse:2090.21792	validation_1-rmse:2642.16636
# [13]	validation_0-rmse:2085.55405	validation_1-rmse:2638.22561
# [14]	validation_0-rmse:2080.51994	validation_1-rmse:2632.09939
# [15]	validation_0-rmse:2057.63837	validation_1-rmse:2607.77392
# [16]	validation_0-rmse:2048.86657	validation_1-rmse:2596.19491
# [17]	validation_0-rmse:2034.69391	validation_1-rmse:2578.28188
# [18]	validation_0-rmse:2027.76691	validation_1-rmse:2569.32644
# [19]	validation_0-rmse:2021.39294	validation_1-rmse:2561.00077
# [20]	validation_0-rmse:2009.82510	validation_1-rmse:2546.42009
# [21]	validation_0-rmse:2005.15239	validation_1-rmse:2543.11955
# [22]	validation_0-rmse:1992.99646	validation_1-rmse:2530.70019
# [23]	validation_0-rmse:1976.37099	validation_1-rmse:2512.22509
# [24]	validation_0-rmse:1959.34725	validation_1-rmse:2494.70740
# [25]	validation_0-rmse:1956.94188	validation_1-rmse:2492.63687
# [26]	validation_0-rmse:1949.55458	validation_1-rmse:2484.60170
# [27]	validation_0-rmse:1948.40251	validation_1-rmse:2482.67359
# [28]	validation_0-rmse:1946.13961	validation_1-rmse:2480.90254
# [29]	validation_0-rmse:1935.58342	validation_1-rmse:2469.31658
# [30]	validation_0-rmse:1935.06477	validation_1-rmse:2468.60775
# [31]	validation_0-rmse:1929.49098	validation_1-rmse:2462.13599
# [32]	validation_0-rmse:1928.97824	validation_1-rmse:2461.29043
# [33]	validation_0-rmse:1924.36409	validation_1-rmse:2455.79511
# [34]	validation_0-rmse:1917.14149	validation_1-rmse:2449.09970
# [35]	validation_0-rmse:1913.70433	validation_1-rmse:2444.78561
# [36]	validation_0-rmse:1913.30856	validation_1-rmse:2444.23439
# [37]	validation_0-rmse:1908.14270	validation_1-rmse:2439.43959
# [38]	validation_0-rmse:1904.45512	validation_1-rmse:2435.19967
# [39]	validation_0-rmse:1894.40459	validation_1-rmse:2420.01711
# [40]	validation_0-rmse:1888.31553	validation_1-rmse:2412.91823
# [41]	validation_0-rmse:1888.18811	validation_1-rmse:2412.76538
# [42]	validation_0-rmse:1885.49469	validation_1-rmse:2409.97616
# [43]	validation_0-rmse:1874.63677	validation_1-rmse:2399.99398
# [44]	validation_0-rmse:1870.17300	validation_1-rmse:2396.13587
# [45]	validation_0-rmse:1869.38099	validation_1-rmse:2396.03542
# [46]	validation_0-rmse:1868.03753	validation_1-rmse:2395.59675
# [47]	validation_0-rmse:1859.37415	validation_1-rmse:2388.50353
# [48]	validation_0-rmse:1858.40035	validation_1-rmse:2388.33403
# [49]	validation_0-rmse:1851.16088	validation_1-rmse:2382.98961
# [50]	validation_0-rmse:1843.16404	validation_1-rmse:2377.08188
# [51]	validation_0-rmse:1837.25996	validation_1-rmse:2372.43402
# [52]	validation_0-rmse:1836.86456	validation_1-rmse:2372.26224
# [53]	validation_0-rmse:1832.93227	validation_1-rmse:2369.56808
# [54]	validation_0-rmse:1830.33706	validation_1-rmse:2368.06194
# [55]	validation_0-rmse:1828.42659	validation_1-rmse:2366.66326
# [56]	validation_0-rmse:1825.80187	validation_1-rmse:2365.72262
# [57]	validation_0-rmse:1823.58934	validation_1-rmse:2363.16515
# [58]	validation_0-rmse:1822.97292	validation_1-rmse:2362.39267
# [59]	validation_0-rmse:1822.30371	validation_1-rmse:2362.29209
# [60]	validation_0-rmse:1814.27091	validation_1-rmse:2353.03304
# [61]	validation_0-rmse:1814.04724	validation_1-rmse:2352.93378
# [62]	validation_0-rmse:1810.19180	validation_1-rmse:2352.15628
# [63]	validation_0-rmse:1810.06047	validation_1-rmse:2352.11995
# [64]	validation_0-rmse:1809.55267	validation_1-rmse:2351.34857
# [65]	validation_0-rmse:1806.25646	validation_1-rmse:2350.71125
# [66]	validation_0-rmse:1805.41773	validation_1-rmse:2350.78323
# [67]	validation_0-rmse:1805.27953	validation_1-rmse:2350.80774
# [68]	validation_0-rmse:1799.53173	validation_1-rmse:2348.13014
# [69]	validation_0-rmse:1797.92336	validation_1-rmse:2346.76277
# [70]	validation_0-rmse:1797.62547	validation_1-rmse:2346.84627
# [71]	validation_0-rmse:1791.19699	validation_1-rmse:2344.25953
# [72]	validation_0-rmse:1790.79296	validation_1-rmse:2344.10495
# [73]	validation_0-rmse:1786.17423	validation_1-rmse:2341.57109
# [74]	validation_0-rmse:1785.72760	validation_1-rmse:2341.16596
# [75]	validation_0-rmse:1784.60915	validation_1-rmse:2339.62143
# [76]	validation_0-rmse:1784.33497	validation_1-rmse:2339.62361
# [77]	validation_0-rmse:1784.04500	validation_1-rmse:2339.84701
# [78]	validation_0-rmse:1782.62669	validation_1-rmse:2338.33330
# [79]	validation_0-rmse:1782.38663	validation_1-rmse:2338.33420
# [80]	validation_0-rmse:1777.65611	validation_1-rmse:2336.78633
# [81]	validation_0-rmse:1770.30881	validation_1-rmse:2328.67861
# [82]	validation_0-rmse:1767.76286	validation_1-rmse:2326.90618
# [83]	validation_0-rmse:1766.98435	validation_1-rmse:2325.74801
# [84]	validation_0-rmse:1766.19215	validation_1-rmse:2324.70310
# [85]	validation_0-rmse:1765.28670	validation_1-rmse:2323.64089
# [86]	validation_0-rmse:1761.77447	validation_1-rmse:2321.72809
# [87]	validation_0-rmse:1761.42624	validation_1-rmse:2321.74552
# [88]	validation_0-rmse:1757.11583	validation_1-rmse:2316.45825
# [89]	validation_0-rmse:1751.43205	validation_1-rmse:2310.65429
# [90]	validation_0-rmse:1749.67747	validation_1-rmse:2309.71148
# [91]	validation_0-rmse:1749.38316	validation_1-rmse:2309.63634
# [92]	validation_0-rmse:1748.88422	validation_1-rmse:2308.95081
# [93]	validation_0-rmse:1744.28550	validation_1-rmse:2304.60185
# [94]	validation_0-rmse:1742.80539	validation_1-rmse:2304.28837
# [95]	validation_0-rmse:1741.71198	validation_1-rmse:2303.32674
# [96]	validation_0-rmse:1740.62500	validation_1-rmse:2303.09942
# [97]	validation_0-rmse:1739.59303	validation_1-rmse:2302.89099
# [98]	validation_0-rmse:1739.34823	validation_1-rmse:2302.87769
# [99]	validation_0-rmse:1739.18360	validation_1-rmse:2302.87816
# [100]	validation_0-rmse:1739.16837	validation_1-rmse:2302.90428
# [101]	validation_0-rmse:1739.12057	validation_1-rmse:2302.90777
# [102]	validation_0-rmse:1739.02332	validation_1-rmse:2302.97955
# [103]	validation_0-rmse:1738.10513	validation_1-rmse:2302.16141
# [104]	validation_0-rmse:1737.99084	validation_1-rmse:2301.86544
# [105]	validation_0-rmse:1737.98736	validation_1-rmse:2301.88697
# [106]	validation_0-rmse:1736.39434	validation_1-rmse:2301.06829
# [107]	validation_0-rmse:1736.36475	validation_1-rmse:2301.02192
# [108]	validation_0-rmse:1733.12944	validation_1-rmse:2300.30047
# [109]	validation_0-rmse:1731.10730	validation_1-rmse:2298.41067
# [110]	validation_0-rmse:1730.90120	validation_1-rmse:2298.40939
# [111]	validation_0-rmse:1730.87901	validation_1-rmse:2298.47786
# [112]	validation_0-rmse:1729.54517	validation_1-rmse:2298.64553
# [113]	validation_0-rmse:1729.41406	validation_1-rmse:2298.60367
# [114]	validation_0-rmse:1727.95343	validation_1-rmse:2298.67329
# [115]	validation_0-rmse:1727.88087	validation_1-rmse:2298.75039
# [116]	validation_0-rmse:1726.22008	validation_1-rmse:2298.28182
# [117]	validation_0-rmse:1724.36576	validation_1-rmse:2298.53040
# [118]	validation_0-rmse:1724.29530	validation_1-rmse:2298.48931
# [119]	validation_0-rmse:1723.79927	validation_1-rmse:2298.38379
# [120]	validation_0-rmse:1722.33703	validation_1-rmse:2297.57531
# [121]	validation_0-rmse:1718.52141	validation_1-rmse:2294.02423
# [122]	validation_0-rmse:1718.48710	validation_1-rmse:2294.04565
# [123]	validation_0-rmse:1717.87924	validation_1-rmse:2293.78002
# [124]	validation_0-rmse:1717.51422	validation_1-rmse:2293.70086
# [125]	validation_0-rmse:1717.32945	validation_1-rmse:2293.65181
# [126]	validation_0-rmse:1717.09981	validation_1-rmse:2293.25312
# [127]	validation_0-rmse:1716.81688	validation_1-rmse:2292.76196
# [128]	validation_0-rmse:1716.45340	validation_1-rmse:2292.79352
# [129]	validation_0-rmse:1715.87964	validation_1-rmse:2292.50386
# [130]	validation_0-rmse:1712.01293	validation_1-rmse:2291.37872
# [131]	validation_0-rmse:1710.11392	validation_1-rmse:2291.42187
# [132]	validation_0-rmse:1708.18669	validation_1-rmse:2291.41606
# [133]	validation_0-rmse:1708.15660	validation_1-rmse:2291.46047
# [134]	validation_0-rmse:1707.22055	validation_1-rmse:2291.45976
# [135]	validation_0-rmse:1703.89382	validation_1-rmse:2288.46462
# [136]	validation_0-rmse:1701.29102	validation_1-rmse:2286.45633
# [137]	validation_0-rmse:1698.93635	validation_1-rmse:2286.55331
# [138]	validation_0-rmse:1698.93620	validation_1-rmse:2286.55766
# [139]	validation_0-rmse:1698.57522	validation_1-rmse:2286.14373
# [140]	validation_0-rmse:1698.40997	validation_1-rmse:2286.15605
# [141]	validation_0-rmse:1698.27641	validation_1-rmse:2285.97072
# [142]	validation_0-rmse:1698.25490	validation_1-rmse:2285.95270
# [143]	validation_0-rmse:1697.99077	validation_1-rmse:2285.58820
# [144]	validation_0-rmse:1695.06578	validation_1-rmse:2282.51783
# [145]	validation_0-rmse:1692.59435	validation_1-rmse:2282.87756
# [146]	validation_0-rmse:1692.58879	validation_1-rmse:2282.91382
# [147]	validation_0-rmse:1690.13449	validation_1-rmse:2280.86668
# [148]	validation_0-rmse:1688.42637	validation_1-rmse:2280.75671
# [149]	validation_0-rmse:1685.32147	validation_1-rmse:2279.71214
# [150]	validation_0-rmse:1684.00225	validation_1-rmse:2279.58650
# [151]	validation_0-rmse:1683.79416	validation_1-rmse:2279.78600
# [152]	validation_0-rmse:1683.33673	validation_1-rmse:2279.78924
# [153]	validation_0-rmse:1681.71474	validation_1-rmse:2280.28861
# [154]	validation_0-rmse:1678.96814	validation_1-rmse:2280.94177
# [155]	validation_0-rmse:1678.47948	validation_1-rmse:2280.80585
# [156]	validation_0-rmse:1676.47398	validation_1-rmse:2280.59916
# [157]	validation_0-rmse:1676.34315	validation_1-rmse:2280.61784
# [158]	validation_0-rmse:1674.78334	validation_1-rmse:2281.56866
# [159]	validation_0-rmse:1673.41625	validation_1-rmse:2282.09660
# [160]	validation_0-rmse:1672.87055	validation_1-rmse:2282.55436
# [161]	validation_0-rmse:1672.79935	validation_1-rmse:2282.46851
# [162]	validation_0-rmse:1671.51150	validation_1-rmse:2282.75804
# [163]	validation_0-rmse:1671.48309	validation_1-rmse:2282.77574
# [164]	validation_0-rmse:1670.71236	validation_1-rmse:2282.80639
# [165]	validation_0-rmse:1670.30988	validation_1-rmse:2282.96727
# [166]	validation_0-rmse:1670.21361	validation_1-rmse:2282.96490
# [167]	validation_0-rmse:1670.02952	validation_1-rmse:2283.01725
# [168]	validation_0-rmse:1668.28447	validation_1-rmse:2283.67475
# [169]	validation_0-rmse:1668.23914	validation_1-rmse:2283.62855
# [170]	validation_0-rmse:1667.88471	validation_1-rmse:2283.66749
# [171]	validation_0-rmse:1666.96598	validation_1-rmse:2283.87479
# [172]	validation_0-rmse:1666.94803	validation_1-rmse:2283.82492
# [173]	validation_0-rmse:1666.86004	validation_1-rmse:2283.77375
# [174]	validation_0-rmse:1666.08759	validation_1-rmse:2283.94166
# [175]	validation_0-rmse:1666.08429	validation_1-rmse:2283.96940
# [176]	validation_0-rmse:1665.05044	validation_1-rmse:2284.11163
# [177]	validation_0-rmse:1665.02909	validation_1-rmse:2284.10245
# [178]	validation_0-rmse:1664.66346	validation_1-rmse:2284.04018
# [179]	validation_0-rmse:1664.64892	validation_1-rmse:2283.97417
# [180]	validation_0-rmse:1664.18701	validation_1-rmse:2283.96503
# [181]	validation_0-rmse:1664.16182	validation_1-rmse:2283.89496
# [182]	validation_0-rmse:1662.82317	validation_1-rmse:2283.85075
# [183]	validation_0-rmse:1661.64440	validation_1-rmse:2284.30232
# [184]	validation_0-rmse:1661.50002	validation_1-rmse:2284.29041
# [185]	validation_0-rmse:1660.91397	validation_1-rmse:2283.80465
# [186]	validation_0-rmse:1660.60960	validation_1-rmse:2283.76241
# [187]	validation_0-rmse:1658.85401	validation_1-rmse:2281.54737
# [188]	validation_0-rmse:1658.82246	validation_1-rmse:2281.60309
# [189]	validation_0-rmse:1658.78772	validation_1-rmse:2281.67178
# [190]	validation_0-rmse:1658.06334	validation_1-rmse:2281.71166
# [191]	validation_0-rmse:1654.51411	validation_1-rmse:2280.12574
# [192]	validation_0-rmse:1654.47256	validation_1-rmse:2280.03540
# [193]	validation_0-rmse:1653.62054	validation_1-rmse:2280.05836
# [194]	validation_0-rmse:1652.27994	validation_1-rmse:2278.74365
# [195]	validation_0-rmse:1651.87860	validation_1-rmse:2278.84407
# [196]	validation_0-rmse:1651.78573	validation_1-rmse:2278.84286
# [197]	validation_0-rmse:1651.69984	validation_1-rmse:2278.87242
# [198]	validation_0-rmse:1649.83820	validation_1-rmse:2277.52999
# [199]	validation_0-rmse:1649.78425	validation_1-rmse:2277.44653
# Score: 2277.4465030434512
# 100%|██████████| 50/50 [01:01<00:00,  1.23s/trial, best loss: 2257.4592475137206]

# %%
best_hparams
# Out:
# {'colsample_bytree': 0.4357299521674466,
#  'eta': 0.03004247244619516,
#  'gamma': 9.0,
#  'max_depth': 4.0,
#  'min_child_weight': 7.0}

# %%
print(f"RMSE: {trials.best_trial['result']['loss']:.3f}")
# Out:
# RMSE: 2257.459

# %% [markdown]
# See feature importance

# %%
importantSorted = np.argsort(trials.best_trial['result']['model'].feature_importances_)[::-1]
for idx in importantSorted[:10]:
    print([train.columns[idx], trials.best_trial['result']['model'].feature_importances_[idx]])
# Out:
# ['dow_Monday', 0.22774337]
# ['weekofyear', 0.18200679]
# ['lag1', 0.082816996]
# ['season_Summer', 0.077220835]
# ['lag10', 0.059872754]
# ['dow_Thursday', 0.05381255]
# ['dow_Friday', 0.049161803]
# ['dayofmonth', 0.039311096]
# ['year', 0.037640724]
# ['dow_Tuesday', 0.032862402]

# %% [markdown]
# Feature importance by gain

# %%
plot_importance(trials.best_trial['result']['model'], max_num_features=10, importance_type='gain')
plt.show();

# %% [markdown]
# Feature importance by weight

# %%
plot_importance(trials.best_trial['result']['model'], max_num_features=10, importance_type='weight')
plt.show();

# %% [markdown]
# We will now use our best model to forecast into the future

# %%
X_full = dummiedf.loc[:, dummiedf.columns != 'revenue']
y_full = dummiedf['revenue']
reg = trials.best_trial['result']['model']  # best model from hyperopt tuning above
reg.fit(X_full, y_full, eval_set=[(X_full, y_full)], verbose=100);
# Out:
# [0]	validation_0-rmse:2562.55973
# [100]	validation_0-rmse:1878.92148
# [199]	validation_0-rmse:1817.03700

# %%
dummiedf.index.max()
# Out:
# Timestamp('2011-12-09 12:00:00')

# %%
# Create hourly timestamps for a year out from our initial maximum date
future = pd.date_range('2011-12-09', '2012-12-01', freq='1h')  
futuredf = pd.DataFrame(index=future)
futuredf['isFuture'] = True
dummiedf['isFuture'] = False
dfWithFuture = pd.concat([dummiedf, futuredf])
dfWithFuture = makeTimeFeatures(dfWithFuture, useidx=True)
# Out:
# C:\Users\Zade\AppData\Local\Temp\ipykernel_6784\2333629205.py:19: FutureWarning: weekofyear and week have been deprecated, please use DatetimeIndex.isocalendar().week instead, which returns a Series. To exactly reproduce the behavior of week and weekofyear and return an Index, you may call pd.Int64Index(idx.isocalendar().week)
#   df['weekofyear'] = df.index.weekofyear

# %%
# Drop the dummified columns as we'll be redoing it for the full dataframe in a moment
dfWithFuture.drop(['season_Spring', 'season_Summer', 'season_Fall', 'season_Winter'], axis=1, inplace=True)
dfWithFuture.drop(['dow_Friday', 'dow_Saturday', 'dow_Sunday', 'dow_Monday', 'dow_Tuesday', 
                   'dow_Wednesday', 'dow_Thursday'],axis=1, inplace=True)
# dfWithFuture.columns

# %%
# Add lag and dummie features
targets = dfWithFuture.revenue.to_dict()
dfWithFuture['lag1'] = (dfWithFuture.index - pd.Timedelta('1 days')).map(targets)
dfWithFuture['lag10'] = (dfWithFuture.index - pd.Timedelta('10 days')).map(targets)
dfWithFuture['lag100'] = (dfWithFuture.index - pd.Timedelta('100 days')).map(targets)
seasondummies = pd.get_dummies(dfWithFuture.season, prefix='season')
dayofweekdummies = pd.get_dummies(dfWithFuture.dayofweek, prefix='dow')
dfWithFuture = pd.concat([dfWithFuture, seasondummies, dayofweekdummies], axis=1)

# %%
# Keep column names consistent
dfWithFuture.rename(columns={"dow_0":"dow_Monday", "dow_1":"dow_Tuesday", "dow_2":"dow_Wednesday",
                             "dow_3":"dow_Thursday", "dow_4":"dow_Friday", "dow_5":"dow_Saturday",
                             "dow_6":"dow_Sunday"}, inplace=True)

# %%
dfWithFuture.drop(['dayofweek', 'season'], axis=1, inplace=True)  # Drop the categorical columns, leave dummies

# %%
futureOnly = dfWithFuture[dfWithFuture.isFuture == True].copy()
# get original columns as list to preserve order for prediction
originalCols = ['month', 'quarter', 'year', 'dayofyear', 'dayofmonth', 'weekofyear', 
                'lag1', 'lag10', 'lag100', 'season_Winter', 'season_Spring', 'season_Summer', 
                'season_Fall', 'dow_Friday', 'dow_Monday', 'dow_Saturday', 'dow_Sunday', 'dow_Thursday', 
                'dow_Tuesday', 'dow_Wednesday']

# %%
futureOnly['revenue'] = reg.predict(futureOnly[originalCols])  # Predict on our future dates

# %%
futureOnly.revenue.plot();
plt.show();

# %% [markdown]
# Again, since there is very little of a slope in our revenue, we see predictions that are roughly horizontal and linear with quite a bit of noise about the horizontal trend line.
